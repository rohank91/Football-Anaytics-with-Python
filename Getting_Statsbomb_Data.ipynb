# %% [markdown]
# <a href="https://colab.research.google.com/github/rohank91/Football-Anaytics-with-Python/blob/main/Getting_Statsbomb_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Scrape the data Data!
#
# Scrape open-data via the Statsbomb Github repo

# %% [markdown]
# ## Import libraries

# %%
# Import required libraries:
import requests
import numpy as np
import pandas as pd

from google.colab import files

# %% [markdown]
# ## Set-up urls for extracting data from [StatsBomb Github repo](https://github.com/statsbomb/open-data)

# %%
scrape_url = "https://raw.githubusercontent.com/statsbomb/open-data/master/data/"
comp_url = scrape_url + "matches/{}/{}.json"
lineup_url = scrape_url + "lineups/{}.json"
event_url = scrape_url + "events/{}.json"

# %%
comp_url.format(11, 42)
# Out:
# 'https://raw.githubusercontent.com/statsbomb/open-data/master/data/matches/11/42.json'

# %%
scrape_url + "matches/" + str(43) + "/" + str(3) + ".json"
# Out:
# 'https://raw.githubusercontent.com/statsbomb/open-data/master/data/matches/43/3.json'

# %%
event_url.format(15326)
# Out:
# 'https://raw.githubusercontent.com/statsbomb/open-data/master/data/events/15326.json'

# %% [markdown]
# ## Competitions meta-data

# %%
scrape_url
# Out:
# 'https://raw.githubusercontent.com/statsbomb/open-data/master/data/'

# %%
# Get the relevant json file
competitions_json = requests.get(url=scrape_url + "competitions.json").json()

# %%
type(competitions_json)
# Out:
# list

# %%
competitions_json[0]
# Out:
# {'competition_gender': 'male',
#  'competition_id': 16,
#  'competition_name': 'Champions League',
#  'country_name': 'Europe',
#  'match_available': '2021-05-19T08:38:06.515138',
#  'match_updated': '2021-05-19T08:38:06.515138',
#  'season_id': 4,
#  'season_name': '2018/2019'}

# %%
for comp in competitions_json:
    print(comp["competition_name"], comp["season_name"])
# Out:
# Champions League 2018/2019
# Champions League 2017/2018
# Champions League 2016/2017
# Champions League 2015/2016
# Champions League 2014/2015
# Champions League 2013/2014
# Champions League 2012/2013
# Champions League 2011/2012
# Champions League 2010/2011
# Champions League 2009/2010
# Champions League 2008/2009
# Champions League 2006/2007
# Champions League 2004/2005
# Champions League 2003/2004
# Champions League 1999/2000
# FA Women's Super League 2019/2020
# FA Women's Super League 2018/2019
# FIFA World Cup 2018
# La Liga 2019/2020
# La Liga 2018/2019
# La Liga 2017/2018
# La Liga 2016/2017
# La Liga 2015/2016
# La Liga 2014/2015
# La Liga 2013/2014
# La Liga 2012/2013
# La Liga 2011/2012
# La Liga 2010/2011
# La Liga 2009/2010
# La Liga 2008/2009
# La Liga 2007/2008
# La Liga 2006/2007
# La Liga 2005/2006
# La Liga 2004/2005
# NWSL 2018
# Premier League 2003/2004
# Women's World Cup 2019

# %%
pd.json_normalize(competitions_json)
# Out:
#     competition_id  ...             match_available
# 0               16  ...  2021-05-19T08:38:06.515138
# 1               16  ...  2021-01-23T21:55:30.425330
# 2               16  ...            2020-07-29T05:00
# 3               16  ...            2020-07-29T05:00
# 4               16  ...            2020-07-29T05:00
# 5               16  ...            2020-07-29T05:00
# 6               16  ...            2020-07-29T05:00
# 7               16  ...            2020-07-29T05:00
# 8               16  ...            2020-07-29T05:00
# 9               16  ...            2020-07-29T05:00
# 10              16  ...  2020-08-30T10:18:39.435424
# 11              16  ...  2021-03-31T04:18:30.437060
# 12              16  ...  2021-04-01T06:18:57.459032
# 13              16  ...  2021-04-01T00:34:59.472485
# 14              16  ...            2020-07-29T05:00
# 15              37  ...  2021-04-28T19:48:01.172671
# 16              37  ...  2021-04-28T19:48:01.166958
# 17              43  ...  2020-10-25T14:03:50.263266
# 18              11  ...  2020-12-18T12:10:38.985394
# 19              11  ...  2021-04-20T03:24:51.029365
# 20              11  ...  2021-05-19T08:38:06.507959
# 21              11  ...  2021-05-19T18:19:46.267118
# 22              11  ...            2020-07-29T05:00
# 23              11  ...            2020-07-29T05:00
# 24              11  ...            2020-07-29T05:00
# 25              11  ...            2020-07-29T05:00
# 26              11  ...            2020-07-29T05:00
# 27              11  ...            2020-07-29T05:00
# 28              11  ...            2020-07-29T05:00
# 29              11  ...            2020-07-29T05:00
# 30              11  ...            2020-07-29T05:00
# 31              11  ...            2020-07-29T05:00
# 32              11  ...            2020-07-29T05:00
# 33              11  ...            2020-07-29T05:00
# 34              49  ...            2020-07-29T05:00
# 35               2  ...  2020-08-31T20:40:28.969635
# 36              72  ...            2020-07-29T05:00
#
# [37 rows x 8 columns]

# %%
sb_comp_meta_df = pd.json_normalize(competitions_json)

# %%
# Save data to csv file on your local system
sb_comp_meta_df.to_csv('sb_competition_metadata.csv')
files.download('sb_competition_metadata.csv')

# %% [markdown]
# ## La-Liga Match Meta data for all seasons

# %%
sb_comp_meta_df
# Out:
#     competition_id  ...             match_available
# 0               16  ...  2021-05-19T08:38:06.515138
# 1               16  ...  2021-01-23T21:55:30.425330
# 2               16  ...            2020-07-29T05:00
# 3               16  ...            2020-07-29T05:00
# 4               16  ...            2020-07-29T05:00
# 5               16  ...            2020-07-29T05:00
# 6               16  ...            2020-07-29T05:00
# 7               16  ...            2020-07-29T05:00
# 8               16  ...            2020-07-29T05:00
# 9               16  ...            2020-07-29T05:00
# 10              16  ...  2020-08-30T10:18:39.435424
# 11              16  ...  2021-03-31T04:18:30.437060
# 12              16  ...  2021-04-01T06:18:57.459032
# 13              16  ...  2021-04-01T00:34:59.472485
# 14              16  ...            2020-07-29T05:00
# 15              37  ...  2021-04-28T19:48:01.172671
# 16              37  ...  2021-04-28T19:48:01.166958
# 17              43  ...  2020-10-25T14:03:50.263266
# 18              11  ...  2020-12-18T12:10:38.985394
# 19              11  ...  2021-04-20T03:24:51.029365
# 20              11  ...  2021-05-19T08:38:06.507959
# 21              11  ...  2021-05-19T18:19:46.267118
# 22              11  ...            2020-07-29T05:00
# 23              11  ...            2020-07-29T05:00
# 24              11  ...            2020-07-29T05:00
# 25              11  ...            2020-07-29T05:00
# 26              11  ...            2020-07-29T05:00
# 27              11  ...            2020-07-29T05:00
# 28              11  ...            2020-07-29T05:00
# 29              11  ...            2020-07-29T05:00
# 30              11  ...            2020-07-29T05:00
# 31              11  ...            2020-07-29T05:00
# 32              11  ...            2020-07-29T05:00
# 33              11  ...            2020-07-29T05:00
# 34              49  ...            2020-07-29T05:00
# 35               2  ...  2020-08-31T20:40:28.969635
# 36              72  ...            2020-07-29T05:00
#
# [37 rows x 8 columns]

# %%
comp_id = 43

# %%
# Slice DF to obtain season ids for all seasons of La Liga:
season_ids = sb_comp_meta_df.loc[sb_comp_meta_df["competition_id"] == comp_id, "season_id"].to_list()

# %%
sb_comp_meta_df.loc[sb_comp_meta_df["competition_id"] == comp_id, "season_id"]
# Out:
# 17    3
# Name: season_id, dtype: int64

# %%
season_ids
# Out:
# [3]

# %%
comp_url
# Out:
# 'https://raw.githubusercontent.com/statsbomb/open-data/master/data/matches/{}/{}.json'

# %%
season_meta_data_df = pd.DataFrame()
for s_id in season_ids:
    season_json = requests.get(url=comp_url.format(comp_id, s_id)).json()
    df = pd.json_normalize(season_json)
    season_meta_data_df = season_meta_data_df.append(df)

# %%
season_meta_data_df.columns
# Out:
# Index(['match_id', 'match_date', 'kick_off', 'home_score', 'away_score',
#        'match_status', 'match_status_360', 'last_updated', 'last_updated_360',
#        'match_week', 'competition.competition_id', 'competition.country_name',
#        'competition.competition_name', 'season.season_id',
#        'season.season_name', 'home_team.home_team_id',
#        'home_team.home_team_name', 'home_team.home_team_gender',
#        'home_team.home_team_group', 'home_team.country.id',
#        'home_team.country.name', 'home_team.managers',
#        'away_team.away_team_id', 'away_team.away_team_name',
#        'away_team.away_team_gender', 'away_team.away_team_group',
#        'away_team.country.id', 'away_team.country.name', 'away_team.managers',
#        'metadata.data_version', 'competition_stage.id',
#        'competition_stage.name', 'stadium.id', 'stadium.name',
#        'stadium.country.id', 'stadium.country.name', 'referee.id',
#        'referee.name', 'referee.country.id', 'referee.country.name'],
#       dtype='object')

# %%
season_meta_data_df["season.season_id"].unique()
# Out:
# array([3])

# %%
season_meta_data_df.columns
# Out:
# Index(['match_id', 'match_date', 'kick_off', 'home_score', 'away_score',
#        'match_status', 'match_status_360', 'last_updated', 'last_updated_360',
#        'match_week', 'competition.competition_id', 'competition.country_name',
#        'competition.competition_name', 'season.season_id',
#        'season.season_name', 'home_team.home_team_id',
#        'home_team.home_team_name', 'home_team.home_team_gender',
#        'home_team.home_team_group', 'home_team.country.id',
#        'home_team.country.name', 'home_team.managers',
#        'away_team.away_team_id', 'away_team.away_team_name',
#        'away_team.away_team_gender', 'away_team.away_team_group',
#        'away_team.country.id', 'away_team.country.name', 'away_team.managers',
#        'metadata.data_version', 'competition_stage.id',
#        'competition_stage.name', 'stadium.id', 'stadium.name',
#        'stadium.country.id', 'stadium.country.name', 'referee.id',
#        'referee.name', 'referee.country.id', 'referee.country.name'],
#       dtype='object')

# %%
season_meta_data_df.head()
# Out:
#    match_id  match_date  ... referee.country.id  referee.country.name
# 0      7581  2018-07-01  ...                NaN                   NaN
# 1      7549  2018-06-22  ...                NaN                   NaN
# 2      7555  2018-06-24  ...              147.0                Mexico
# 3      7529  2018-06-16  ...                NaN                   NaN
# 4      7548  2018-06-22  ...              160.0           Netherlands
#
# [5 rows x 40 columns]

# %%
season_meta_data_df.groupby(["season.season_id"])["match_id"].count()
# Out:
# season.season_id
# 3    64
# Name: match_id, dtype: int64

# %%
# Save data to csv file on your local system
season_meta_data_df.to_csv('season_matchwise_data.csv')
files.download('season_matchwise_data.csv')

# %% [markdown]
# ## Event data for one match in La-Liga

# %%
match_id_list = season_meta_data_df["match_id"].unique()

# %%
event_json = requests.get(url=event_url.format(match_id_list[0])).json()

# %%
event_json
# Out:
# [{'duration': 0.0,
#   'id': '0aa135b8-37b4-4482-adc7-f02e85a19bec',
#   'index': 1,
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'possession': 1,
#   'possession_team': {'id': 785, 'name': 'Croatia'},
#   'second': 0,
#   'tactics': {'formation': 4141,
#    'lineup': [{'jersey_number': 23,
#      'player': {'id': 3444, 'name': 'Danijel Subašić'},
#      'position': {'id': 1, 'name': 'Goalkeeper'}},
#     {'jersey_number': 2,
#      'player': {'id': 5461, 'name': 'Šime Vrsaljko'},
#      'position': {'id': 2, 'name': 'Right Back'}},
#     {'jersey_number': 6,
#      'player': {'id': 3471, 'name': 'Dejan Lovren'},
#      'position': {'id': 3, 'name': 'Right Center Back'}},
#     {'jersey_number': 21,
#      'player': {'id': 5468, 'name': 'Domagoj Vida'},
#      'position': {'id': 5, 'name': 'Left Center Back'}},
#     {'jersey_number': 3,
#      'player': {'id': 5457, 'name': 'Ivan Strinić'},
#      'position': {'id': 6, 'name': 'Left Back'}},
#     {'jersey_number': 11,
#      'player': {'id': 5469, 'name': 'Marcelo Brozović'},
#      'position': {'id': 10, 'name': 'Center Defensive Midfield'}},
#     {'jersey_number': 18,
#      'player': {'id': 5465, 'name': 'Ante Rebić'},
#      'position': {'id': 12, 'name': 'Right Midfield'}},
#     {'jersey_number': 10,
#      'player': {'id': 5463, 'name': 'Luka Modrić'},
#      'position': {'id': 13, 'name': 'Right Center Midfield'}},
#     {'jersey_number': 7,
#      'player': {'id': 5470, 'name': 'Ivan Rakitić'},
#      'position': {'id': 15, 'name': 'Left Center Midfield'}},
#     {'jersey_number': 4,
#      'player': {'id': 5474, 'name': 'Ivan Perišić'},
#      'position': {'id': 16, 'name': 'Left Midfield'}},
#     {'jersey_number': 17,
#      'player': {'id': 5472, 'name': 'Mario Mandžukić'},
#      'position': {'id': 23, 'name': 'Center Forward'}}]},
#   'team': {'id': 785, 'name': 'Croatia'},
#   'timestamp': '00:00:00.000',
#   'type': {'id': 35, 'name': 'Starting XI'}},
#  {'duration': 0.0,
#   'id': '086b7750-936b-4ffd-9a00-bfd72c7a0f26',
#   'index': 2,
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'possession': 1,
#   'possession_team': {'id': 785, 'name': 'Croatia'},
#   'second': 0,
#   'tactics': {'formation': 4411,
#    'lineup': [{'jersey_number': 1,
#      'player': {'id': 3815, 'name': 'Kasper Schmeichel'},
#      'position': {'id': 1, 'name': 'Goalkeeper'}},
#     {'jersey_number': 14,
#      'player': {'id': 4763, 'name': 'Henrik Dalsgaard'},
#      'position': {'id': 2, 'name': 'Right Back'}},
#     {'jersey_number': 4,
#      'player': {'id': 5534, 'name': 'Simon Thorup Kjær'},
#      'position': {'id': 3, 'name': 'Right Center Back'}},
#     {'jersey_number': 13,
#      'player': {'id': 3027, 'name': 'Mathias Jattah-Njie Jørgensen'},
#      'position': {'id': 5, 'name': 'Left Center Back'}},
#     {'jersey_number': 5,
#      'player': {'id': 6355, 'name': 'Jonas Knudsen'},
#      'position': {'id': 6, 'name': 'Left Back'}},
#     {'jersey_number': 6,
#      'player': {'id': 3959, 'name': 'Andreas Christensen'},
#      'position': {'id': 13, 'name': 'Right Center Midfield'}},
#     {'jersey_number': 8,
#      'player': {'id': 5527, 'name': 'Thomas Delaney'},
#      'position': {'id': 15, 'name': 'Left Center Midfield'}},
#     {'jersey_number': 20,
#      'player': {'id': 5536, 'name': 'Yussuf Yurary Poulsen'},
#      'position': {'id': 17, 'name': 'Right Wing'}},
#     {'jersey_number': 11,
#      'player': {'id': 4447, 'name': 'Martin Braithwaite Christensen'},
#      'position': {'id': 21, 'name': 'Left Wing'}},
#     {'jersey_number': 21,
#      'player': {'id': 5732, 'name': 'Andreas Evald Cornelius'},
#      'position': {'id': 23, 'name': 'Center Forward'}},
#     {'jersey_number': 10,
#      'player': {'id': 3043, 'name': 'Christian Dannemann Eriksen'},
#      'position': {'id': 25, 'name': 'Secondary Striker'}}]},
#   'team': {'id': 776, 'name': 'Denmark'},
#   'timestamp': '00:00:00.000',
#   'type': {'id': 35, 'name': 'Starting XI'}},
#  {'duration': 0.0,
#   'id': '53f0c3f9-129e-47b5-ba77-ae9d214df56f',
#   'index': 3,
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'possession': 1,
#   'possession_team': {'id': 785, 'name': 'Croatia'},
#   'related_events': ['49233ae2-594f-43c9-a58c-a6a0b8f99ee2'],
#   'second': 0,
#   'team': {'id': 785, 'name': 'Croatia'},
#   'timestamp': '00:00:00.000',
#   'type': {'id': 18, 'name': 'Half Start'}},
#  {'duration': 9.813,
#   'id': '49233ae2-594f-43c9-a58c-a6a0b8f99ee2',
#   'index': 4,
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'possession': 1,
#   'possession_team': {'id': 785, 'name': 'Croatia'},
#   'related_events': ['53f0c3f9-129e-47b5-ba77-ae9d214df56f'],
#   'second': 0,
#   'team': {'id': 776, 'name': 'Denmark'},
#   'timestamp': '00:00:00.000',
#   'type': {'id': 18, 'name': 'Half Start'}},
#  {'duration': 1.64,
#   'id': 'ec5ba260-9bd3-4c5a-b7a5-9f9168ea905d',
#   'index': 5,
#   'location': [61.0, 41.0],
#   'minute': 0,
#   'pass': {'angle': -2.976444,
#    'body_part': {'id': 40, 'name': 'Right Foot'},
#    'end_location': [37.0, 37.0],
#    'height': {'id': 1, 'name': 'Ground Pass'},
#    'length': 24.33105,
#    'recipient': {'id': 3027, 'name': 'Mathias Jattah-Njie Jørgensen'},
#    'type': {'id': 65, 'name': 'Kick Off'}},
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 3043, 'name': 'Christian Dannemann Eriksen'},
#   'position': {'id': 25, 'name': 'Secondary Striker'},
#   'possession': 2,
#   'possession_team': {'id': 776, 'name': 'Denmark'},
#   'related_events': ['797a8169-c17f-4dbe-aa71-406cf0cf1bd6'],
#   'second': 1,
#   'team': {'id': 776, 'name': 'Denmark'},
#   'timestamp': '00:00:01.013',
#   'type': {'id': 30, 'name': 'Pass'}},
#  {'id': '797a8169-c17f-4dbe-aa71-406cf0cf1bd6',
#   'index': 6,
#   'location': [37.0, 37.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 3027, 'name': 'Mathias Jattah-Njie Jørgensen'},
#   'position': {'id': 5, 'name': 'Left Center Back'},
#   'possession': 2,
#   'possession_team': {'id': 776, 'name': 'Denmark'},
#   'related_events': ['ec5ba260-9bd3-4c5a-b7a5-9f9168ea905d'],
#   'second': 2,
#   'team': {'id': 776, 'name': 'Denmark'},
#   'timestamp': '00:00:02.653',
#   'type': {'id': 42, 'name': 'Ball Receipt*'}},
#  {'carry': {'end_location': [38.0, 42.0]},
#   'duration': 1.4,
#   'id': 'abb799d1-73d8-4119-b23f-40f79765f8f8',
#   'index': 7,
#   'location': [37.0, 37.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 3027, 'name': 'Mathias Jattah-Njie Jørgensen'},
#   'position': {'id': 5, 'name': 'Left Center Back'},
#   'possession': 2,
#   'possession_team': {'id': 776, 'name': 'Denmark'},
#   'related_events': ['797a8169-c17f-4dbe-aa71-406cf0cf1bd6',
#    '9d3fc438-e85d-49fa-8ff4-21cb3bcc54b1',
#    'e9f18d71-3b31-46f4-aa6b-1dcda3b53a34'],
#   'second': 2,
#   'team': {'id': 776, 'name': 'Denmark'},
#   'timestamp': '00:00:02.653',
#   'type': {'id': 43, 'name': 'Carry'},
#   'under_pressure': True},
#  {'duration': 0.573,
#   'id': 'e9f18d71-3b31-46f4-aa6b-1dcda3b53a34',
#   'index': 8,
#   'location': [77.0, 41.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 5472, 'name': 'Mario Mandžukić'},
#   'position': {'id': 23, 'name': 'Center Forward'},
#   'possession': 2,
#   'possession_team': {'id': 776, 'name': 'Denmark'},
#   'related_events': ['9d3fc438-e85d-49fa-8ff4-21cb3bcc54b1',
#    'abb799d1-73d8-4119-b23f-40f79765f8f8'],
#   'second': 3,
#   'team': {'id': 785, 'name': 'Croatia'},
#   'timestamp': '00:00:03.720',
#   'type': {'id': 17, 'name': 'Pressure'}},
#  {'duration': 2.947,
#   'id': '9d3fc438-e85d-49fa-8ff4-21cb3bcc54b1',
#   'index': 9,
#   'location': [38.0, 42.0],
#   'minute': 0,
#   'pass': {'angle': 0.2489627,
#    'body_part': {'id': 40, 'name': 'Right Foot'},
#    'end_location': [97.0, 57.0],
#    'height': {'id': 3, 'name': 'High Pass'},
#    'length': 60.876926,
#    'outcome': {'id': 9, 'name': 'Incomplete'}},
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 3027, 'name': 'Mathias Jattah-Njie Jørgensen'},
#   'position': {'id': 5, 'name': 'Left Center Back'},
#   'possession': 2,
#   'possession_team': {'id': 776, 'name': 'Denmark'},
#   'related_events': ['5be94fcb-9612-4f00-82b6-3728f4f1b45c',
#    'e9f18d71-3b31-46f4-aa6b-1dcda3b53a34'],
#   'second': 4,
#   'team': {'id': 776, 'name': 'Denmark'},
#   'timestamp': '00:00:04.053',
#   'type': {'id': 30, 'name': 'Pass'},
#   'under_pressure': True},
#  {'duration': 2.293,
#   'id': '5be94fcb-9612-4f00-82b6-3728f4f1b45c',
#   'index': 10,
#   'location': [24.0, 24.0],
#   'minute': 0,
#   'pass': {'angle': 0.35877067,
#    'body_part': {'id': 37, 'name': 'Head'},
#    'end_location': [48.0, 33.0],
#    'height': {'id': 3, 'name': 'High Pass'},
#    'length': 25.632011,
#    'outcome': {'id': 9, 'name': 'Incomplete'},
#    'type': {'id': 66, 'name': 'Recovery'}},
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 5468, 'name': 'Domagoj Vida'},
#   'position': {'id': 5, 'name': 'Left Center Back'},
#   'possession': 2,
#   'possession_team': {'id': 776, 'name': 'Denmark'},
#   'related_events': ['0370171b-81a7-49e6-809c-3ade48258b5e',
#    '9d3fc438-e85d-49fa-8ff4-21cb3bcc54b1'],
#   'second': 7,
#   'team': {'id': 785, 'name': 'Croatia'},
#   'timestamp': '00:00:07.000',
#   'type': {'id': 30, 'name': 'Pass'}},
#  {'duration': 1.079,
#   'id': '0370171b-81a7-49e6-809c-3ade48258b5e',
#   'index': 11,
#   'location': [73.0, 48.0],
#   'minute': 0,
#   'pass': {'angle': 3.1415927,
#    'body_part': {'id': 37, 'name': 'Head'},
#    'end_location': [68.0, 48.0],
#    'height': {'id': 3, 'name': 'High Pass'},
#    'length': 5.0,
#    'recipient': {'id': 3959, 'name': 'Andreas Christensen'},
#    'type': {'id': 66, 'name': 'Recovery'}},
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 5527, 'name': 'Thomas Delaney'},
#   'position': {'id': 15, 'name': 'Left Center Midfield'},
#   'possession': 2,
#   'possession_team': {'id': 776, 'name': 'Denmark'},
#   'related_events': ['4b80dce0-f114-4050-9725-ddd7e715b236',
#    '5be94fcb-9612-4f00-82b6-3728f4f1b45c'],
#   'second': 9,
#   'team': {'id': 776, 'name': 'Denmark'},
#   'timestamp': '00:00:09.293',
#   'type': {'id': 30, 'name': 'Pass'}},
#  {'id': '4b80dce0-f114-4050-9725-ddd7e715b236',
#   'index': 12,
#   'location': [68.0, 48.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 3959, 'name': 'Andreas Christensen'},
#   'position': {'id': 13, 'name': 'Right Center Midfield'},
#   'possession': 2,
#   'possession_team': {'id': 776, 'name': 'Denmark'},
#   'related_events': ['0370171b-81a7-49e6-809c-3ade48258b5e'],
#   'second': 10,
#   'team': {'id': 776, 'name': 'Denmark'},
#   'timestamp': '00:00:10.372',
#   'type': {'id': 42, 'name': 'Ball Receipt*'}},
#  {'duration': 1.467,
#   'id': '6a5b1b10-3e93-4621-be9f-05820c0c31bb',
#   'index': 13,
#   'location': [75.0, 50.0],
#   'minute': 0,
#   'pass': {'aerial_won': True,
#    'angle': 0.4048918,
#    'end_location': [82.0, 53.0],
#    'height': {'id': 3, 'name': 'High Pass'},
#    'length': 7.615773,
#    'outcome': {'id': 9, 'name': 'Incomplete'}},
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 3959, 'name': 'Andreas Christensen'},
#   'position': {'id': 13, 'name': 'Right Center Midfield'},
#   'possession': 2,
#   'possession_team': {'id': 776, 'name': 'Denmark'},
#   'related_events': ['28eb913b-3148-4291-bb5e-a0079158f6ac',
#    '5325dad9-df7b-40e1-bc61-e67e5860fe7c'],
#   'second': 11,
#   'team': {'id': 776, 'name': 'Denmark'},
#   'timestamp': '00:00:11.053',
#   'type': {'id': 30, 'name': 'Pass'},
#   'under_pressure': True},
#  {'duel': {'type': {'id': 10, 'name': 'Aerial Lost'}},
#   'duration': 0.0,
#   'id': '28eb913b-3148-4291-bb5e-a0079158f6ac',
#   'index': 14,
#   'location': [46.0, 31.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 5463, 'name': 'Luka Modrić'},
#   'position': {'id': 13, 'name': 'Right Center Midfield'},
#   'possession': 2,
#   'possession_team': {'id': 776, 'name': 'Denmark'},
#   'related_events': ['6a5b1b10-3e93-4621-be9f-05820c0c31bb'],
#   'second': 11,
#   'team': {'id': 785, 'name': 'Croatia'},
#   'timestamp': '00:00:11.053',
#   'type': {'id': 4, 'name': 'Duel'},
#   'under_pressure': True},
#  {'duration': 1.613,
#   'id': '5325dad9-df7b-40e1-bc61-e67e5860fe7c',
#   'index': 15,
#   'location': [39.0, 28.0],
#   'minute': 0,
#   'pass': {'angle': 0.21109334,
#    'body_part': {'id': 37, 'name': 'Head'},
#    'end_location': [53.0, 31.0],
#    'height': {'id': 3, 'name': 'High Pass'},
#    'length': 14.3178215,
#    'outcome': {'id': 9, 'name': 'Incomplete'},
#    'recipient': {'id': 5463, 'name': 'Luka Modrić'},
#    'type': {'id': 66, 'name': 'Recovery'}},
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 5469, 'name': 'Marcelo Brozović'},
#   'position': {'id': 10, 'name': 'Center Defensive Midfield'},
#   'possession': 2,
#   'possession_team': {'id': 776, 'name': 'Denmark'},
#   'related_events': ['192f7270-5735-474c-8a0a-330acab4853a',
#    '6a5b1b10-3e93-4621-be9f-05820c0c31bb',
#    'dc59bcaf-27f6-493f-9b01-312461b14d40'],
#   'second': 12,
#   'team': {'id': 785, 'name': 'Croatia'},
#   'timestamp': '00:00:12.520',
#   'type': {'id': 30, 'name': 'Pass'}},
#  {'ball_receipt': {'outcome': {'id': 9, 'name': 'Incomplete'}},
#   'id': '192f7270-5735-474c-8a0a-330acab4853a',
#   'index': 16,
#   'location': [52.0, 32.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 5463, 'name': 'Luka Modrić'},
#   'position': {'id': 13, 'name': 'Right Center Midfield'},
#   'possession': 2,
#   'possession_team': {'id': 776, 'name': 'Denmark'},
#   'related_events': ['5325dad9-df7b-40e1-bc61-e67e5860fe7c'],
#   'second': 14,
#   'team': {'id': 785, 'name': 'Croatia'},
#   'timestamp': '00:00:14.133',
#   'type': {'id': 42, 'name': 'Ball Receipt*'}},
#  {'duel': {'type': {'id': 10, 'name': 'Aerial Lost'}},
#   'duration': 0.0,
#   'id': '5994c24d-8d6b-45c9-8c28-ace9a445f605',
#   'index': 17,
#   'location': [53.0, 31.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 5463, 'name': 'Luka Modrić'},
#   'position': {'id': 13, 'name': 'Right Center Midfield'},
#   'possession': 2,
#   'possession_team': {'id': 776, 'name': 'Denmark'},
#   'related_events': ['dc59bcaf-27f6-493f-9b01-312461b14d40'],
#   'second': 14,
#   'team': {'id': 785, 'name': 'Croatia'},
#   'timestamp': '00:00:14.133',
#   'type': {'id': 4, 'name': 'Duel'},
#   'under_pressure': True},
#  {'duration': 0.919,
#   'id': 'dc59bcaf-27f6-493f-9b01-312461b14d40',
#   'index': 18,
#   'location': [68.0, 50.0],
#   'minute': 0,
#   'pass': {'aerial_won': True,
#    'angle': 0.11065722,
#    'end_location': [77.0, 51.0],
#    'height': {'id': 3, 'name': 'High Pass'},
#    'length': 9.055386,
#    'recipient': {'id': 3043, 'name': 'Christian Dannemann Eriksen'},
#    'type': {'id': 66, 'name': 'Recovery'}},
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 3959, 'name': 'Andreas Christensen'},
#   'position': {'id': 13, 'name': 'Right Center Midfield'},
#   'possession': 2,
#   'possession_team': {'id': 776, 'name': 'Denmark'},
#   'related_events': ['5325dad9-df7b-40e1-bc61-e67e5860fe7c',
#    '5994c24d-8d6b-45c9-8c28-ace9a445f605',
#    'ad5869e3-c085-4bb9-b89d-0c89b93d63ae'],
#   'second': 14,
#   'team': {'id': 776, 'name': 'Denmark'},
#   'timestamp': '00:00:14.133',
#   'type': {'id': 30, 'name': 'Pass'},
#   'under_pressure': True},
#  {'id': 'ad5869e3-c085-4bb9-b89d-0c89b93d63ae',
#   'index': 19,
#   'location': [77.0, 51.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 3043, 'name': 'Christian Dannemann Eriksen'},
#   'position': {'id': 25, 'name': 'Secondary Striker'},
#   'possession': 2,
#   'possession_team': {'id': 776, 'name': 'Denmark'},
#   'related_events': ['dc59bcaf-27f6-493f-9b01-312461b14d40'],
#   'second': 15,
#   'team': {'id': 776, 'name': 'Denmark'},
#   'timestamp': '00:00:15.052',
#   'type': {'id': 42, 'name': 'Ball Receipt*'}},
#  {'duration': 1.027,
#   'id': 'f0c2d54d-a9b0-4691-a5bc-053d36511959',
#   'index': 20,
#   'location': [77.0, 55.0],
#   'minute': 0,
#   'pass': {'angle': 0.35877067,
#    'body_part': {'id': 37, 'name': 'Head'},
#    'end_location': [85.0, 58.0],
#    'height': {'id': 3, 'name': 'High Pass'},
#    'length': 8.5440035,
#    'outcome': {'id': 9, 'name': 'Incomplete'},
#    'recipient': {'id': 5536, 'name': 'Yussuf Yurary Poulsen'}},
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 3043, 'name': 'Christian Dannemann Eriksen'},
#   'position': {'id': 25, 'name': 'Secondary Striker'},
#   'possession': 2,
#   'possession_team': {'id': 776, 'name': 'Denmark'},
#   'related_events': ['717268ee-18fc-462c-bfc1-f657d7fb9e3d',
#    'ecda38ae-2e07-4f8e-9a37-a3e14c1d84e5'],
#   'second': 15,
#   'team': {'id': 776, 'name': 'Denmark'},
#   'timestamp': '00:00:15.253',
#   'type': {'id': 30, 'name': 'Pass'}},
#  {'ball_receipt': {'outcome': {'id': 9, 'name': 'Incomplete'}},
#   'id': '717268ee-18fc-462c-bfc1-f657d7fb9e3d',
#   'index': 21,
#   'location': [88.0, 55.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 5536, 'name': 'Yussuf Yurary Poulsen'},
#   'position': {'id': 17, 'name': 'Right Wing'},
#   'possession': 2,
#   'possession_team': {'id': 776, 'name': 'Denmark'},
#   'related_events': ['f0c2d54d-a9b0-4691-a5bc-053d36511959'],
#   'second': 16,
#   'team': {'id': 776, 'name': 'Denmark'},
#   'timestamp': '00:00:16.280',
#   'type': {'id': 42, 'name': 'Ball Receipt*'}},
#  {'duration': 1.613,
#   'id': 'ecda38ae-2e07-4f8e-9a37-a3e14c1d84e5',
#   'index': 22,
#   'location': [36.0, 23.0],
#   'minute': 0,
#   'pass': {'angle': -0.69473827,
#    'body_part': {'id': 37, 'name': 'Head'},
#    'end_location': [42.0, 18.0],
#    'height': {'id': 3, 'name': 'High Pass'},
#    'length': 7.81025,
#    'outcome': {'id': 9, 'name': 'Incomplete'},
#    'recipient': {'id': 5474, 'name': 'Ivan Perišić'},
#    'type': {'id': 66, 'name': 'Recovery'}},
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 5468, 'name': 'Domagoj Vida'},
#   'position': {'id': 5, 'name': 'Left Center Back'},
#   'possession': 2,
#   'possession_team': {'id': 776, 'name': 'Denmark'},
#   'related_events': ['5636124b-64ce-4fb6-84b2-a511a0129de4',
#    'ea80f9a1-64ee-4457-b8c5-bbe7e8795fed',
#    'f0c2d54d-a9b0-4691-a5bc-053d36511959'],
#   'second': 16,
#   'team': {'id': 785, 'name': 'Croatia'},
#   'timestamp': '00:00:16.280',
#   'type': {'id': 30, 'name': 'Pass'}},
#  {'ball_receipt': {'outcome': {'id': 9, 'name': 'Incomplete'}},
#   'id': 'ea80f9a1-64ee-4457-b8c5-bbe7e8795fed',
#   'index': 23,
#   'location': [41.0, 20.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 5474, 'name': 'Ivan Perišić'},
#   'position': {'id': 16, 'name': 'Left Midfield'},
#   'possession': 2,
#   'possession_team': {'id': 776, 'name': 'Denmark'},
#   'related_events': ['ecda38ae-2e07-4f8e-9a37-a3e14c1d84e5'],
#   'second': 17,
#   'team': {'id': 785, 'name': 'Croatia'},
#   'timestamp': '00:00:17.893',
#   'type': {'id': 42, 'name': 'Ball Receipt*'}},
#  {'duel': {'type': {'id': 10, 'name': 'Aerial Lost'}},
#   'duration': 0.0,
#   'id': '40d5059d-b884-4fbd-8aab-4d25ad7b6d26',
#   'index': 24,
#   'location': [42.0, 18.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 5474, 'name': 'Ivan Perišić'},
#   'position': {'id': 16, 'name': 'Left Midfield'},
#   'possession': 2,
#   'possession_team': {'id': 776, 'name': 'Denmark'},
#   'related_events': ['5636124b-64ce-4fb6-84b2-a511a0129de4'],
#   'second': 17,
#   'team': {'id': 785, 'name': 'Croatia'},
#   'timestamp': '00:00:17.893',
#   'type': {'id': 4, 'name': 'Duel'},
#   'under_pressure': True},
#  {'duration': 1.48,
#   'id': '5636124b-64ce-4fb6-84b2-a511a0129de4',
#   'index': 25,
#   'location': [79.0, 63.0],
#   'minute': 0,
#   'pass': {'aerial_won': True,
#    'angle': -0.98279375,
#    'end_location': [89.0, 48.0],
#    'height': {'id': 3, 'name': 'High Pass'},
#    'length': 18.027756,
#    'recipient': {'id': 4447, 'name': 'Martin Braithwaite Christensen'},
#    'type': {'id': 66, 'name': 'Recovery'}},
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 4763, 'name': 'Henrik Dalsgaard'},
#   'position': {'id': 2, 'name': 'Right Back'},
#   'possession': 2,
#   'possession_team': {'id': 776, 'name': 'Denmark'},
#   'related_events': ['40d5059d-b884-4fbd-8aab-4d25ad7b6d26',
#    '8d4f0d15-aaa5-4bc6-978d-6d609a63dfad',
#    'ecda38ae-2e07-4f8e-9a37-a3e14c1d84e5'],
#   'second': 17,
#   'team': {'id': 776, 'name': 'Denmark'},
#   'timestamp': '00:00:17.893',
#   'type': {'id': 30, 'name': 'Pass'},
#   'under_pressure': True},
#  {'id': '8d4f0d15-aaa5-4bc6-978d-6d609a63dfad',
#   'index': 26,
#   'location': [89.0, 48.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 4447, 'name': 'Martin Braithwaite Christensen'},
#   'position': {'id': 21, 'name': 'Left Wing'},
#   'possession': 2,
#   'possession_team': {'id': 776, 'name': 'Denmark'},
#   'related_events': ['5636124b-64ce-4fb6-84b2-a511a0129de4'],
#   'second': 19,
#   'team': {'id': 776, 'name': 'Denmark'},
#   'timestamp': '00:00:19.373',
#   'type': {'id': 42, 'name': 'Ball Receipt*'}},
#  {'carry': {'end_location': [88.0, 54.0]},
#   'duration': 0.04,
#   'id': '2331f5ea-85f8-4cd5-b258-f9624dfbb5ec',
#   'index': 27,
#   'location': [89.0, 48.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 4447, 'name': 'Martin Braithwaite Christensen'},
#   'position': {'id': 21, 'name': 'Left Wing'},
#   'possession': 2,
#   'possession_team': {'id': 776, 'name': 'Denmark'},
#   'related_events': ['8d4f0d15-aaa5-4bc6-978d-6d609a63dfad',
#    'de5b7950-d971-4d8b-846f-920365d448fd'],
#   'second': 19,
#   'team': {'id': 776, 'name': 'Denmark'},
#   'timestamp': '00:00:19.373',
#   'type': {'id': 43, 'name': 'Carry'}},
#  {'duration': 1.84,
#   'id': 'de5b7950-d971-4d8b-846f-920365d448fd',
#   'index': 28,
#   'location': [88.0, 54.0],
#   'minute': 0,
#   'pass': {'angle': -0.06241881,
#    'body_part': {'id': 40, 'name': 'Right Foot'},
#    'end_location': [104.0, 53.0],
#    'height': {'id': 3, 'name': 'High Pass'},
#    'length': 16.03122,
#    'outcome': {'id': 9, 'name': 'Incomplete'},
#    'recipient': {'id': 5732, 'name': 'Andreas Evald Cornelius'}},
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 4447, 'name': 'Martin Braithwaite Christensen'},
#   'position': {'id': 21, 'name': 'Left Wing'},
#   'possession': 2,
#   'possession_team': {'id': 776, 'name': 'Denmark'},
#   'related_events': ['003a1db4-7c1b-4f0e-9e15-f341e28e52d3',
#    'f3b1170b-6e32-4b21-b44b-c2a5397fb2f4'],
#   'second': 19,
#   'team': {'id': 776, 'name': 'Denmark'},
#   'timestamp': '00:00:19.413',
#   'type': {'id': 30, 'name': 'Pass'}},
#  {'ball_receipt': {'outcome': {'id': 9, 'name': 'Incomplete'}},
#   'id': '003a1db4-7c1b-4f0e-9e15-f341e28e52d3',
#   'index': 29,
#   'location': [104.0, 53.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 5732, 'name': 'Andreas Evald Cornelius'},
#   'position': {'id': 23, 'name': 'Center Forward'},
#   'possession': 2,
#   'possession_team': {'id': 776, 'name': 'Denmark'},
#   'related_events': ['de5b7950-d971-4d8b-846f-920365d448fd'],
#   'second': 21,
#   'team': {'id': 776, 'name': 'Denmark'},
#   'timestamp': '00:00:21.253',
#   'type': {'id': 42, 'name': 'Ball Receipt*'}},
#  {'duration': 2.826,
#   'id': 'f3b1170b-6e32-4b21-b44b-c2a5397fb2f4',
#   'index': 30,
#   'location': [17.0, 28.0],
#   'minute': 0,
#   'pass': {'angle': -1.6078165,
#    'body_part': {'id': 40, 'name': 'Right Foot'},
#    'end_location': [16.0, 1.0],
#    'height': {'id': 1, 'name': 'Ground Pass'},
#    'length': 27.018513,
#    'outcome': {'id': 75, 'name': 'Out'},
#    'recipient': {'id': 5457, 'name': 'Ivan Strinić'},
#    'type': {'id': 66, 'name': 'Recovery'}},
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 5468, 'name': 'Domagoj Vida'},
#   'position': {'id': 5, 'name': 'Left Center Back'},
#   'possession': 2,
#   'possession_team': {'id': 776, 'name': 'Denmark'},
#   'related_events': ['d20213c7-4687-4a1c-b401-e19befa8b663',
#    'de5b7950-d971-4d8b-846f-920365d448fd'],
#   'second': 21,
#   'team': {'id': 785, 'name': 'Croatia'},
#   'timestamp': '00:00:21.253',
#   'type': {'id': 30, 'name': 'Pass'}},
#  {'ball_receipt': {'outcome': {'id': 9, 'name': 'Incomplete'}},
#   'id': 'd20213c7-4687-4a1c-b401-e19befa8b663',
#   'index': 31,
#   'location': [14.0, 5.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'player': {'id': 5457, 'name': 'Ivan Strinić'},
#   'position': {'id': 6, 'name': 'Left Back'},
#   'possession': 2,
#   'possession_team': {'id': 776, 'name': 'Denmark'},
#   'related_events': ['f3b1170b-6e32-4b21-b44b-c2a5397fb2f4'],
#   'second': 24,
#   'team': {'id': 785, 'name': 'Croatia'},
#   'timestamp': '00:00:24.079',
#   'type': {'id': 42, 'name': 'Ball Receipt*'}},
#  {'duration': 2.56,
#   'id': '356b63ca-b534-4dc6-a5b2-e0515fe1b3b2',
#   'index': 32,
#   'location': [105.0, 80.0],
#   'minute': 0,
#   'pass': {'angle': -1.3734008,
#    'end_location': [113.0, 40.0],
#    'height': {'id': 3, 'name': 'High Pass'},
#    'length': 40.792156,
#    'recipient': {'id': 5527, 'name': 'Thomas Delaney'},
#    'switch': True,
#    'type': {'id': 67, 'name': 'Throw-in'}},
#   'period': 1,
#   'play_pattern': {'id': 4, 'name': 'From Throw In'},
#   'player': {'id': 6355, 'name': 'Jonas Knudsen'},
#   'position': {'id': 6, 'name': 'Left Back'},
#   'possession': 3,
#   'possession_team': {'id': 776, 'name': 'Denmark'},
#   'related_events': ['a040b433-2ee2-4244-8f39-4973729c97b2'],
#   'second': 53,
#   'team': {'id': 776, 'name': 'Denmark'},
#   'timestamp': '00:00:53.013',
#   'type': {'id': 30, 'name': 'Pass'}},
#  {'id': 'a040b433-2ee2-4244-8f39-4973729c97b2',
#   'index': 33,
#   'location': [113.0, 40.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 4, 'name': 'From Throw In'},
#   'player': {'id': 5527, 'name': 'Thomas Delaney'},
#   'position': {'id': 15, 'name': 'Left Center Midfield'},
#   'possession': 3,
#   'possession_team': {'id': 776, 'name': 'Denmark'},
#   'related_events': ['356b63ca-b534-4dc6-a5b2-e0515fe1b3b2'],
#   'second': 55,
#   'team': {'id': 776, 'name': 'Denmark'},
#   'timestamp': '00:00:55.573',
#   'type': {'id': 42, 'name': 'Ball Receipt*'}},
#  {'carry': {'end_location': [114.0, 38.0]},
#   'duration': 0.68,
#   'id': '9d69f8e1-5701-4d4b-ac95-ac6a30fba9fa',
#   'index': 34,
#   'location': [113.0, 40.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 4, 'name': 'From Throw In'},
#   'player': {'id': 5527, 'name': 'Thomas Delaney'},
#   'position': {'id': 15, 'name': 'Left Center Midfield'},
#   'possession': 3,
#   'possession_team': {'id': 776, 'name': 'Denmark'},
#   'related_events': ['a040b433-2ee2-4244-8f39-4973729c97b2',
#    'e5c989a0-5e4c-428d-9024-bffa382d7c45'],
#   'second': 55,
#   'team': {'id': 776, 'name': 'Denmark'},
#   'timestamp': '00:00:55.573',
#   'type': {'id': 43, 'name': 'Carry'}},
#  {'duration': 0.84,
#   'id': 'e5c989a0-5e4c-428d-9024-bffa382d7c45',
#   'index': 35,
#   'location': [114.0, 38.0],
#   'minute': 0,
#   'pass': {'angle': -1.5707964,
#    'assisted_shot_id': '45a8bcb7-b2a0-4f9c-8ec9-ff2d8e50e696',
#    'body_part': {'id': 38, 'name': 'Left Foot'},
#    'end_location': [114.0, 33.0],
#    'goal_assist': True,
#    'height': {'id': 1, 'name': 'Ground Pass'},
#    'length': 5.0,
#    'recipient': {'id': 3027, 'name': 'Mathias Jattah-Njie Jørgensen'}},
#   'period': 1,
#   'play_pattern': {'id': 4, 'name': 'From Throw In'},
#   'player': {'id': 5527, 'name': 'Thomas Delaney'},
#   'position': {'id': 15, 'name': 'Left Center Midfield'},
#   'possession': 3,
#   'possession_team': {'id': 776, 'name': 'Denmark'},
#   'related_events': ['fb06d9da-55b4-4c7b-8268-971a6629ab4a'],
#   'second': 56,
#   'team': {'id': 776, 'name': 'Denmark'},
#   'timestamp': '00:00:56.253',
#   'type': {'id': 30, 'name': 'Pass'}},
#  {'id': 'fb06d9da-55b4-4c7b-8268-971a6629ab4a',
#   'index': 36,
#   'location': [114.0, 33.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 4, 'name': 'From Throw In'},
#   'player': {'id': 3027, 'name': 'Mathias Jattah-Njie Jørgensen'},
#   'position': {'id': 5, 'name': 'Left Center Back'},
#   'possession': 3,
#   'possession_team': {'id': 776, 'name': 'Denmark'},
#   'related_events': ['e5c989a0-5e4c-428d-9024-bffa382d7c45'],
#   'second': 57,
#   'team': {'id': 776, 'name': 'Denmark'},
#   'timestamp': '00:00:57.093',
#   'type': {'id': 42, 'name': 'Ball Receipt*'}},
#  {'carry': {'end_location': [115.0, 34.0]},
#   'duration': 0.227,
#   'id': 'c67ac937-b1f8-484b-ae34-ae1e641f5739',
#   'index': 37,
#   'location': [114.0, 33.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 4, 'name': 'From Throw In'},
#   'player': {'id': 3027, 'name': 'Mathias Jattah-Njie Jørgensen'},
#   'position': {'id': 5, 'name': 'Left Center Back'},
#   'possession': 3,
#   'possession_team': {'id': 776, 'name': 'Denmark'},
#   'related_events': ['45a8bcb7-b2a0-4f9c-8ec9-ff2d8e50e696',
#    'fb06d9da-55b4-4c7b-8268-971a6629ab4a'],
#   'second': 57,
#   'team': {'id': 776, 'name': 'Denmark'},
#   'timestamp': '00:00:57.093',
#   'type': {'id': 43, 'name': 'Carry'}},
#  {'duration': 0.64,
#   'id': '45a8bcb7-b2a0-4f9c-8ec9-ff2d8e50e696',
#   'index': 38,
#   'location': [115.0, 34.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 4, 'name': 'From Throw In'},
#   'player': {'id': 3027, 'name': 'Mathias Jattah-Njie Jørgensen'},
#   'position': {'id': 5, 'name': 'Left Center Back'},
#   'possession': 3,
#   'possession_team': {'id': 776, 'name': 'Denmark'},
#   'related_events': ['6d329784-01e5-44df-b6cc-f55723dfc7cf'],
#   'second': 57,
#   'shot': {'body_part': {'id': 38, 'name': 'Left Foot'},
#    'end_location': [119.0, 39.7, 0.2],
#    'freeze_frame': [{'location': [120.0, 38.0],
#      'player': {'id': 3444, 'name': 'Danijel Subašić'},
#      'position': {'id': 1, 'name': 'Goalkeeper'},
#      'teammate': False},
#     {'location': [114.0, 36.0],
#      'player': {'id': 5527, 'name': 'Thomas Delaney'},
#      'position': {'id': 15, 'name': 'Left Center Midfield'},
#      'teammate': True},
#     {'location': [114.0, 41.0],
#      'player': {'id': 5536, 'name': 'Yussuf Yurary Poulsen'},
#      'position': {'id': 17, 'name': 'Right Wing'},
#      'teammate': True},
#     {'location': [99.0, 34.0],
#      'player': {'id': 4447, 'name': 'Martin Braithwaite Christensen'},
#      'position': {'id': 21, 'name': 'Left Wing'},
#      'teammate': True},
#     {'location': [105.0, 52.0],
#      'player': {'id': 5470, 'name': 'Ivan Rakitić'},
#      'position': {'id': 15, 'name': 'Left Center Midfield'},
#      'teammate': False},
#     {'location': [105.0, 41.0],
#      'player': {'id': 3043, 'name': 'Christian Dannemann Eriksen'},
#      'position': {'id': 25, 'name': 'Secondary Striker'},
#      'teammate': True},
#     {'location': [118.0, 37.0],
#      'player': {'id': 5468, 'name': 'Domagoj Vida'},
#      'position': {'id': 5, 'name': 'Left Center Back'},
#      'teammate': False},
#     {'location': [116.0, 35.0],
#      'player': {'id': 5461, 'name': 'Šime Vrsaljko'},
#      'position': {'id': 2, 'name': 'Right Back'},
#      'teammate': False},
#     {'location': [116.0, 41.0],
#      'player': {'id': 3471, 'name': 'Dejan Lovren'},
#      'position': {'id': 3, 'name': 'Right Center Back'},
#      'teammate': False},
#     {'location': [115.0, 37.0],
#      'player': {'id': 5465, 'name': 'Ante Rebić'},
#      'position': {'id': 12, 'name': 'Right Midfield'},
#      'teammate': False},
#     {'location': [112.0, 35.0],
#      'player': {'id': 5469, 'name': 'Marcelo Brozović'},
#      'position': {'id': 10, 'name': 'Center Defensive Midfield'},
#      'teammate': False},
#     {'location': [113.0, 43.0],
#      'player': {'id': 5534, 'name': 'Simon Thorup Kjær'},
#      'position': {'id': 3, 'name': 'Right Center Back'},
#      'teammate': True},
#     {'location': [111.0, 43.0],
#      'player': {'id': 5472, 'name': 'Mario Mandžukić'},
#      'position': {'id': 23, 'name': 'Center Forward'},
#      'teammate': False},
#     {'location': [115.0, 45.0],
#      'player': {'id': 5457, 'name': 'Ivan Strinić'},
#      'position': {'id': 6, 'name': 'Left Back'},
#      'teammate': False},
#     {'location': [113.0, 45.0],
#      'player': {'id': 5732, 'name': 'Andreas Evald Cornelius'},
#      'position': {'id': 23, 'name': 'Center Forward'},
#      'teammate': True},
#     {'location': [117.0, 47.0],
#      'player': {'id': 5474, 'name': 'Ivan Perišić'},
#      'position': {'id': 16, 'name': 'Left Midfield'},
#      'teammate': False},
#     {'location': [115.0, 47.0],
#      'player': {'id': 3959, 'name': 'Andreas Christensen'},
#      'position': {'id': 13, 'name': 'Right Center Midfield'},
#      'teammate': True},
#     {'location': [103.0, 34.0],
#      'player': {'id': 5463, 'name': 'Luka Modrić'},
#      'position': {'id': 13, 'name': 'Right Center Midfield'},
#      'teammate': False}],
#    'key_pass_id': 'e5c989a0-5e4c-428d-9024-bffa382d7c45',
#    'outcome': {'id': 97, 'name': 'Goal'},
#    'statsbomb_xg': 0.07408676,
#    'technique': {'id': 93, 'name': 'Normal'},
#    'type': {'id': 87, 'name': 'Open Play'}},
#   'team': {'id': 776, 'name': 'Denmark'},
#   'timestamp': '00:00:57.320',
#   'type': {'id': 16, 'name': 'Shot'}},
#  {'duration': 0.0,
#   'goalkeeper': {'body_part': {'id': 39, 'name': 'Left Hand'},
#    'outcome': {'id': 58, 'name': 'Touched In'},
#    'position': {'id': 44, 'name': 'Set'},
#    'technique': {'id': 45, 'name': 'Diving'},
#    'type': {'id': 26, 'name': 'Goal Conceded'}},
#   'id': '6d329784-01e5-44df-b6cc-f55723dfc7cf',
#   'index': 39,
#   'location': [1.0, 43.0],
#   'minute': 0,
#   'period': 1,
#   'play_pattern': {'id': 4, 'name': 'From Throw In'},
#   'player': {'id': 3444, 'name': 'Danijel Subašić'},
#   'position': {'id': 1, 'name': 'Goalkeeper'},
#   'possession': 3,
#   'possession_team': {'id': 776, 'name': 'Denmark'},
#   'related_events': ['45a8bcb7-b2a0-4f9c-8ec9-ff2d8e50e696'],
#   'second': 57,
#   'team': {'id': 785, 'name': 'Croatia'},
#   'timestamp': '00:00:57.960',
#   'type': {'id': 23, 'name': 'Goal Keeper'}},
#  {'id': 'ab7022c9-135b-48a2-b5e2-90ed5c1d9a68',
#   'index': 40,
#   'minute': 2,
#   'period': 1,
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'possession': 4,
#   'possession_team': {'id': 776, 'name': 'Denmark'},
#   'second': 10,
#   'team': {'id': 776, 'name': 'Denmark'},
#   'timestamp': '00:02:10.140',
#   'type': {'id': 5, 'name': 'Camera On'}},
#  {'duration': 0.453,
#   'id': 'b7383977-ee6f-4784-b177-a4cc2ce3c6c1',
#   'index': 41,
#   'location': [81.0, 10.0],
#   'minute': 2,
#   'period': 1,
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'player': {'id': 5472, 'name': 'Mario Mandžukić'},
#   'position': {'id': 23, 'name': 'Center Forward'},
#   'possession': 4,
#   'possession_team': {'id': 776, 'name': 'Denmark'},
#   'related_events': ['bb375811-ce78-4d01-aae7-92effb5faa4d'],
#   'second': 10,
#   'team': {'id': 785, 'name': 'Croatia'},
#   'timestamp': '00:02:10.880',
#   'type': {'id': 17, 'name': 'Pressure'}},
#  {'duration': 1.36,
#   'id': 'bb375811-ce78-4d01-aae7-92effb5faa4d',
#   'index': 42,
#   'location': [34.0, 74.0],
#   'minute': 2,
#   'pass': {'angle': -1.7196863,
#    'body_part': {'id': 40, 'name': 'Right Foot'},
#    'end_location': [31.0, 54.0],
#    'height': {'id': 1, 'name': 'Ground Pass'},
#    'length': 20.22375,
#    'recipient': {'id': 3027, 'name': 'Mathias Jattah-Njie Jørgensen'}},
#   'period': 1,
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'player': {'id': 5534, 'name': 'Simon Thorup Kjær'},
#   'position': {'id': 3, 'name': 'Right Center Back'},
#   'possession': 4,
#   'possession_team': {'id': 776, 'name': 'Denmark'},
#   'related_events': ['919105e7-9a47-4713-a96d-3aaa956a5b8f',
#    'b7383977-ee6f-4784-b177-a4cc2ce3c6c1'],
#   'second': 11,
#   'team': {'id': 776, 'name': 'Denmark'},
#   'timestamp': '00:02:11.173',
#   'type': {'id': 30, 'name': 'Pass'},
#   'under_pressure': True},
#  {'duration': 0.493,
#   'id': '4478868f-e150-43d4-b996-fe822eb82076',
#   'index': 43,
#   'location': [89.0, 19.0],
#   'minute': 2,
#   'period': 1,
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'player': {'id': 5472, 'name': 'Mario Mandžukić'},
#   'position': {'id': 23, 'name': 'Center Forward'},
#   'possession': 4,
#   'possession_team': {'id': 776, 'name': 'Denmark'},
#   'related_events': ['0f4596cf-0af7-410b-8d84-8c419b047936',
#    '919105e7-9a47-4713-a96d-3aaa956a5b8f'],
#   'second': 12,
#   'team': {'id': 785, 'name': 'Croatia'},
#   'timestamp': '00:02:12.480',
#   'type': {'id': 17, 'name': 'Pressure'}},
#  {'id': '919105e7-9a47-4713-a96d-3aaa956a5b8f',
#   'index': 44,
#   'location': [31.0, 54.0],
#   'minute': 2,
#   'period': 1,
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'player': {'id': 3027, 'name': 'Mathias Jattah-Njie Jørgensen'},
#   'position': {'id': 5, 'name': 'Left Center Back'},
#   'possession': 4,
#   'possession_team': {'id': 776, 'name': 'Denmark'},
#   'related_events': ['4478868f-e150-43d4-b996-fe822eb82076',
#    'bb375811-ce78-4d01-aae7-92effb5faa4d'],
#   'second': 12,
#   'team': {'id': 776, 'name': 'Denmark'},
#   'timestamp': '00:02:12.533',
#   'type': {'id': 42, 'name': 'Ball Receipt*'},
#   'under_pressure': True},
#  {'carry': {'end_location': [31.0, 60.0]},
#   'duration': 0.68,
#   'id': '0f4596cf-0af7-410b-8d84-8c419b047936',
#   'index': 45,
#   'location': [31.0, 54.0],
#   'minute': 2,
#   'period': 1,
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'player': {'id': 3027, 'name': 'Mathias Jattah-Njie Jørgensen'},
#   'position': {'id': 5, 'name': 'Left Center Back'},
#   'possession': 4,
#   'possession_team': {'id': 776, 'name': 'Denmark'},
#   'related_events': ['4478868f-e150-43d4-b996-fe822eb82076',
#    '919105e7-9a47-4713-a96d-3aaa956a5b8f',
#    'd58d0da2-2329-464c-8de5-fd9744350d20'],
#   'second': 12,
#   'team': {'id': 776, 'name': 'Denmark'},
#   'timestamp': '00:02:12.533',
#   'type': {'id': 43, 'name': 'Carry'},
#   'under_pressure': True},
#  {'duration': 0.879,
#   'id': 'd58d0da2-2329-464c-8de5-fd9744350d20',
#   'index': 46,
#   'location': [31.0, 60.0],
#   'minute': 2,
#   'pass': {'angle': 0.32175055,
#    'body_part': {'id': 40, 'name': 'Right Foot'},
#    'end_location': [40.0, 63.0],
#    'height': {'id': 1, 'name': 'Ground Pass'},
#    'length': 9.486833,
#    'recipient': {'id': 3959, 'name': 'Andreas Christensen'}},
#   'period': 1,
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'player': {'id': 3027, 'name': 'Mathias Jattah-Njie Jørgensen'},
#   'position': {'id': 5, 'name': 'Left Center Back'},
#   'possession': 4,
#   'possession_team': {'id': 776, 'name': 'Denmark'},
#   'related_events': ['d5a24b90-488f-4ab6-a91e-0a6e9c5b5800'],
#   'second': 13,
#   'team': {'id': 776, 'name': 'Denmark'},
#   'timestamp': '00:02:13.213',
#   'type': {'id': 30, 'name': 'Pass'}},
#  {'duration': 0.573,
#   'id': '621c3640-9a6c-49b8-af02-42e970a97fa2',
#   'index': 47,
#   'location': [74.0, 29.0],
#   'minute': 2,
#   'period': 1,
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'player': {'id': 5470, 'name': 'Ivan Rakitić'},
#   'position': {'id': 15, 'name': 'Left Center Midfield'},
#   'possession': 4,
#   'possession_team': {'id': 776, 'name': 'Denmark'},
#   'related_events': ['b49bd22b-14f1-439b-946c-575cc2d97fba',
#    'd5a24b90-488f-4ab6-a91e-0a6e9c5b5800'],
#   'second': 13,
#   'team': {'id': 785, 'name': 'Croatia'},
#   'timestamp': '00:02:13.600',
#   'type': {'id': 17, 'name': 'Pressure'}},
#  {'id': 'd5a24b90-488f-4ab6-a91e-0a6e9c5b5800',
#   'index': 48,
#   'location': [40.0, 63.0],
#   'minute': 2,
#   'period': 1,
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'player': {'id': 3959, 'name': 'Andreas Christensen'},
#   'position': {'id': 13, 'name': 'Right Center Midfield'},
#   'possession': 4,
#   'possession_team': {'id': 776, 'name': 'Denmark'},
#   'related_events': ['621c3640-9a6c-49b8-af02-42e970a97fa2',
#    'd58d0da2-2329-464c-8de5-fd9744350d20'],
#   'second': 14,
#   'team': {'id': 776, 'name': 'Denmark'},
#   'timestamp': '00:02:14.092',
#   'type': {'id': 42, 'name': 'Ball Receipt*'},
#   'under_pressure': True},
#  {'carry': {'end_location': [40.0, 63.0]},
#   'duration': 0.161,
#   'id': 'b49bd22b-14f1-439b-946c-575cc2d97fba',
#   'index': 49,
#   'location': [40.0, 63.0],
#   'minute': 2,
#   'period': 1,
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'player': {'id': 3959, 'name': 'Andreas Christensen'},
#   'position': {'id': 13, 'name': 'Right Center Midfield'},
#   'possession': 4,
#   'possession_team': {'id': 776, 'name': 'Denmark'},
#   'related_events': ['621c3640-9a6c-49b8-af02-42e970a97fa2',
#    '95e60a5d-b642-427b-a7f8-389cdfee59eb',
#    'd5a24b90-488f-4ab6-a91e-0a6e9c5b5800'],
#   'second': 14,
#   'team': {'id': 776, 'name': 'Denmark'},
#   'timestamp': '00:02:14.092',
#   'type': {'id': 43, 'name': 'Carry'},
#   'under_pressure': True},
#  {'duration': 1.44,
#   'id': '95e60a5d-b642-427b-a7f8-389cdfee59eb',
#   'index': 50,
#   'location': [40.0, 63.0],
#   'minute': 2,
#   'pass': {'angle': 2.5829933,
#    'body_part': {'id': 40, 'name': 'Right Foot'},
#    'end_location': [24.0, 73.0],
#    'height': {'id': 1, 'name': 'Ground Pass'},
#    'length': 18.867962,
#    'recipient': {'id': 5534, 'name': 'Simon Thorup Kjær'}},
#   'period': 1,
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'player': {'id': 3959, 'name': 'Andreas Christensen'},
#   'position': {'id': 13, 'name': 'Right Center Midfield'},
#   'possession': 4,
#   'possession_team': {'id': 776, 'name': 'Denmark'},
#   'related_events': ['d74754f6-9873-42a7-9c01-76572bc23c66'],
#   'second': 14,
#   'team': {'id': 776, 'name': 'Denmark'},
#   'timestamp': '00:02:14.253',
#   'type': {'id': 30, 'name': 'Pass'}},
#  {'id': 'd74754f6-9873-42a7-9c01-76572bc23c66',
#   'index': 51,
#   'location': [24.0, 73.0],
#   'minute': 2,
#   'period': 1,
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'player': {'id': 5534, 'name': 'Simon Thorup Kjær'},
#   'position': {'id': 3, 'name': 'Right Center Back'},
#   'possession': 4,
#   'possession_team': {'id': 776, 'name': 'Denmark'},
#   'related_events': ['95e60a5d-b642-427b-a7f8-389cdfee59eb'],
#   'second': 15,
#   'team': {'id': 776, 'name': 'Denmark'},
#   'timestamp': '00:02:15.693',
#   'type': {'id': 42, 'name': 'Ball Receipt*'}},
#  {'carry': {'end_location': [20.0, 72.0]},
#   'duration': 1.32,
#   'id': '94524203-a1aa-43ce-9d99-61a80de04438',
#   'index': 52,
#   'location': [24.0, 73.0],
#   'minute': 2,
#   'period': 1,
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'player': {'id': 5534, 'name': 'Simon Thorup Kjær'},
#   'position': {'id': 3, 'name': 'Right Center Back'},
#   'possession': 4,
#   'possession_team': {'id': 776, 'name': 'Denmark'},
#   'related_events': ['ce936f6f-ef75-4c0c-93ab-640534d7c3e5',
#    'd74754f6-9873-42a7-9c01-76572bc23c66',
#    'e0da73b5-d0a1-4c44-9cba-664ba9807a94'],
#   'second': 15,
#   'team': {'id': 776, 'name': 'Denmark'},
#   'timestamp': '00:02:15.693',
#   'type': {'id': 43, 'name': 'Carry'},
#   'under_pressure': True},
#  {'duration': 0.493,
#   'id': 'e0da73b5-d0a1-4c44-9cba-664ba9807a94',
#   'index': 53,
#   'location': [94.0, 14.0],
#   'minute': 2,
#   'period': 1,
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'player': {'id': 5470, 'name': 'Ivan Rakitić'},
#   'position': {'id': 15, 'name': 'Left Center Midfield'},
#   'possession': 4,
#   'possession_team': {'id': 776, 'name': 'Denmark'},
#   'related_events': ['94524203-a1aa-43ce-9d99-61a80de04438'],
#   'second': 16,
#   'team': {'id': 785, 'name': 'Croatia'},
#   'timestamp': '00:02:16.400',
#   'type': {'id': 17, 'name': 'Pressure'}},
#  {'duration': 1.08,
#   'id': 'ce936f6f-ef75-4c0c-93ab-640534d7c3e5',
#   'index': 54,
#   'location': [20.0, 72.0],
#   'minute': 2,
#   'pass': {'angle': 0.39060703,
#    'body_part': {'id': 40, 'name': 'Right Foot'},
#    'end_location': [37.0, 79.0],
#    'height': {'id': 2, 'name': 'Low Pass'},
#    'length': 18.384777,
#    'outcome': {'id': 75, 'name': 'Out'},
#    'recipient': {'id': 4763, 'name': 'Henrik Dalsgaard'}},
#   'period': 1,
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'player': {'id': 5534, 'name': 'Simon Thorup Kjær'},
#   'position': {'id': 3, 'name': 'Right Center Back'},
#   'possession': 4,
#   'possession_team': {'id': 776, 'name': 'Denmark'},
#   'related_events': ['868b5d17-f017-4c65-a4aa-fed80ae761a2'],
#   'second': 17,
#   'team': {'id': 776, 'name': 'Denmark'},
#   'timestamp': '00:02:17.013',
#   'type': {'id': 30, 'name': 'Pass'}},
#  {'ball_receipt': {'outcome': {'id': 9, 'name': 'Incomplete'}},
#   'id': '868b5d17-f017-4c65-a4aa-fed80ae761a2',
#   'index': 55,
#   'location': [39.0, 79.0],
#   'minute': 2,
#   'period': 1,
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'player': {'id': 4763, 'name': 'Henrik Dalsgaard'},
#   'position': {'id': 2, 'name': 'Right Back'},
#   'possession': 4,
#   'possession_team': {'id': 776, 'name': 'Denmark'},
#   'related_events': ['ce936f6f-ef75-4c0c-93ab-640534d7c3e5'],
#   'second': 18,
#   'team': {'id': 776, 'name': 'Denmark'},
#   'timestamp': '00:02:18.093',
#   'type': {'id': 42, 'name': 'Ball Receipt*'}},
#  {'duration': 1.08,
#   'id': 'acba47b5-613b-4705-b090-e1a50512e7bf',
#   'index': 56,
#   'location': [90.0, 2.0],
#   'minute': 2,
#   'pass': {'angle': 0.9652517,
#    'end_location': [99.0, 15.0],
#    'height': {'id': 2, 'name': 'Low Pass'},
#    'length': 15.811388,
#    'recipient': {'id': 5470, 'name': 'Ivan Rakitić'},
#    'type': {'id': 67, 'name': 'Throw-in'}},
#   'period': 1,
#   'play_pattern': {'id': 4, 'name': 'From Throw In'},
#   'player': {'id': 5457, 'name': 'Ivan Strinić'},
#   'position': {'id': 6, 'name': 'Left Back'},
#   'possession': 5,
#   'possession_team': {'id': 785, 'name': 'Croatia'},
#   'related_events': ['5085de9f-6fde-4a9a-a3b0-f86c20a3136b'],
#   'second': 27,
#   'team': {'id': 785, 'name': 'Croatia'},
#   'timestamp': '00:02:27.440',
#   'type': {'id': 30, 'name': 'Pass'}},
#  {'id': '5085de9f-6fde-4a9a-a3b0-f86c20a3136b',
#   'index': 57,
#   'location': [99.0, 15.0],
#   'minute': 2,
#   'period': 1,
#   'play_pattern': {'id': 4, 'name': 'From Throw In'},
#   'player': {'id': 5470, 'name': 'Ivan Rakitić'},
#   'position': {'id': 15, 'name': 'Left Center Midfield'},
#   'possession': 5,
#   'possession_team': {'id': 785, 'name': 'Croatia'},
#   'related_events': ['acba47b5-613b-4705-b090-e1a50512e7bf'],
#   'second': 28,
#   'team': {'id': 785, 'name': 'Croatia'},
#   'timestamp': '00:02:28.520',
#   'type': {'id': 42, 'name': 'Ball Receipt*'}},
#  {'duration': 0.733,
#   'id': '01e8f706-8eb7-422a-8a9e-e28a3c2075ea',
#   'index': 58,
#   'location': [99.0, 15.0],
#   'minute': 2,
#   'pass': {'angle': -1.2722974,
#    'body_part': {'id': 40, 'name': 'Right Foot'},
#    'end_location': [103.0, 2.0],
#    'height': {'id': 1, 'name': 'Ground Pass'},
#    'length': 13.601471,
#    'recipient': {'id': 5474, 'name': 'Ivan Perišić'}},
#   'period': 1,
#   'play_pattern': {'id': 4, 'name': 'From Throw In'},
#   'player': {'id': 5470, 'name': 'Ivan Rakitić'},
#   'position': {'id': 15, 'name': 'Left Center Midfield'},
#   'possession': 5,
#   'possession_team': {'id': 785, 'name': 'Croatia'},
#   'related_events': ['04fffd27-981f-4f56-b8cb-d2d4cfd6d28b'],
#   'second': 28,
#   'team': {'id': 785, 'name': 'Croatia'},
#   'timestamp': '00:02:28.520',
#   'type': {'id': 30, 'name': 'Pass'}},
#  {'duration': 1.119,
#   'id': '03c50dbe-ea52-4677-9a7b-8630f2d84423',
#   'index': 59,
#   'location': [18.0, 79.0],
#   'minute': 2,
#   'period': 1,
#   'play_pattern': {'id': 4, 'name': 'From Throw In'},
#   'player': {'id': 4763, 'name': 'Henrik Dalsgaard'},
#   'position': {'id': 2, 'name': 'Right Back'},
#   'possession': 5,
#   'possession_team': {'id': 785, 'name': 'Croatia'},
#   'related_events': ['04fffd27-981f-4f56-b8cb-d2d4cfd6d28b',
#    '274cb695-9eb8-436b-98be-e382b9ce5397',
#    '2f6b8889-e16b-40f9-a88a-2e03cacf2701'],
#   'second': 28,
#   'team': {'id': 776, 'name': 'Denmark'},
#   'timestamp': '00:02:28.973',
#   'type': {'id': 17, 'name': 'Pressure'}},
#  {'id': '04fffd27-981f-4f56-b8cb-d2d4cfd6d28b',
#   'index': 60,
#   'location': [103.0, 2.0],
#   'minute': 2,
#   'period': 1,
#   'play_pattern': {'id': 4, 'name': 'From Throw In'},
#   'player': {'id': 5474, 'name': 'Ivan Perišić'},
#   'position': {'id': 16, 'name': 'Left Midfield'},
#   'possession': 5,
#   'possession_team': {'id': 785, 'name': 'Croatia'},
#   'related_events': ['01e8f706-8eb7-422a-8a9e-e28a3c2075ea',
#    '03c50dbe-ea52-4677-9a7b-8630f2d84423'],
#   'second': 29,
#   'team': {'id': 785, 'name': 'Croatia'},
#   'timestamp': '00:02:29.253',
#   'type': {'id': 42, 'name': 'Ball Receipt*'},
# ...
#   'type': {'id': 42, 'name': 'Ball Receipt*'}},
#  {'carry': {'end_location': [94.0, 32.0]},
#   'duration': 2.627,
#   'id': '387cfe27-acdf-4a6d-b507-5eff26675d5c',
#   'index': 985,
#   'location': [86.0, 18.0],
#   'minute': 28,
#   'period': 1,
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'player': {'id': 5470, 'name': 'Ivan Rakitić'},
#   'position': {'id': 15, 'name': 'Left Center Midfield'},
#   'possession': 46,
#   'possession_team': {'id': 785, 'name': 'Croatia'},
#   'related_events': ['5ed1a261-f56e-47aa-b040-18812d4186d6',
#    'd8fd027c-e43a-49d2-8d68-2405ad816e8e'],
#   'second': 16,
#   'team': {'id': 785, 'name': 'Croatia'},
#   'timestamp': '00:28:16.373',
#   'type': {'id': 43, 'name': 'Carry'}},
#  {'duration': 0.8,
#   'id': 'd8fd027c-e43a-49d2-8d68-2405ad816e8e',
#   'index': 986,
#   'location': [94.0, 32.0],
#   'minute': 28,
#   'period': 1,
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'player': {'id': 5470, 'name': 'Ivan Rakitić'},
#   'position': {'id': 15, 'name': 'Left Center Midfield'},
#   'possession': 46,
#   'possession_team': {'id': 785, 'name': 'Croatia'},
#   'related_events': ['d54cf120-ad56-4d15-b6d4-d9b6ce7d9478'],
#   'second': 19,
#   'shot': {'body_part': {'id': 40, 'name': 'Right Foot'},
#    'end_location': [116.0, 37.8, 2.1],
#    'freeze_frame': [{'location': [86.0, 34.0],
#      'player': {'id': 5463, 'name': 'Luka Modrić'},
#      'position': {'id': 13, 'name': 'Right Center Midfield'},
#      'teammate': True},
#     {'location': [104.0, 30.0],
#      'player': {'id': 5534, 'name': 'Simon Thorup Kjær'},
#      'position': {'id': 3, 'name': 'Right Center Back'},
#      'teammate': False},
#     {'location': [98.0, 32.0],
#      'player': {'id': 3027, 'name': 'Mathias Jattah-Njie Jørgensen'},
#      'position': {'id': 5, 'name': 'Left Center Back'},
#      'teammate': False},
#     {'location': [94.0, 50.0],
#      'player': {'id': 6355, 'name': 'Jonas Knudsen'},
#      'position': {'id': 6, 'name': 'Left Back'},
#      'teammate': False},
#     {'location': [93.0, 35.0],
#      'player': {'id': 5527, 'name': 'Thomas Delaney'},
#      'position': {'id': 15, 'name': 'Left Center Midfield'},
#      'teammate': False},
#     {'location': [85.0, 29.0],
#      'player': {'id': 3959, 'name': 'Andreas Christensen'},
#      'position': {'id': 13, 'name': 'Right Center Midfield'},
#      'teammate': False},
#     {'location': [86.0, 15.0],
#      'player': {'id': 5536, 'name': 'Yussuf Yurary Poulsen'},
#      'position': {'id': 17, 'name': 'Right Wing'},
#      'teammate': False},
#     {'location': [86.0, 48.0],
#      'player': {'id': 5474, 'name': 'Ivan Perišić'},
#      'position': {'id': 16, 'name': 'Left Midfield'},
#      'teammate': True},
#     {'location': [86.0, 44.0],
#      'player': {'id': 5472, 'name': 'Mario Mandžukić'},
#      'position': {'id': 23, 'name': 'Center Forward'},
#      'teammate': True},
#     {'location': [117.0, 38.0],
#      'player': {'id': 3815, 'name': 'Kasper Schmeichel'},
#      'position': {'id': 1, 'name': 'Goalkeeper'},
#      'teammate': False},
#     {'location': [102.0, 24.0],
#      'player': {'id': 5465, 'name': 'Ante Rebić'},
#      'position': {'id': 12, 'name': 'Right Midfield'},
#      'teammate': True},
#     {'location': [103.0, 24.0],
#      'player': {'id': 4763, 'name': 'Henrik Dalsgaard'},
#      'position': {'id': 2, 'name': 'Right Back'},
#      'teammate': False}],
#    'key_pass_id': '3e0cd3a9-d842-4134-8268-fb4e9b408c1d',
#    'outcome': {'id': 100, 'name': 'Saved'},
#    'statsbomb_xg': 0.03258096,
#    'technique': {'id': 93, 'name': 'Normal'},
#    'type': {'id': 87, 'name': 'Open Play'}},
#   'team': {'id': 785, 'name': 'Croatia'},
#   'timestamp': '00:28:19.000',
#   'type': {'id': 16, 'name': 'Shot'}},
#  {'goalkeeper': {'body_part': {'id': 35, 'name': 'Both Hands'},
#    'outcome': {'id': 53, 'name': 'In Play Safe'},
#    'position': {'id': 44, 'name': 'Set'},
#    'technique': {'id': 45, 'name': 'Diving'},
#    'type': {'id': 33, 'name': 'Shot Saved'}},
#   'id': 'd54cf120-ad56-4d15-b6d4-d9b6ce7d9478',
#   'index': 987,
#   'location': [4.0, 43.0],
#   'minute': 28,
#   'period': 1,
#   'play_pattern': {'id': 6, 'name': 'From Counter'},
#   'player': {'id': 3815, 'name': 'Kasper Schmeichel'},
#   'position': {'id': 1, 'name': 'Goalkeeper'},
#   'possession': 46,
#   'possession_team': {'id': 785, 'name': 'Croatia'},
#   'related_events': ['d8fd027c-e43a-49d2-8d68-2405ad816e8e'],
#   'second': 19,
#   'team': {'id': 776, 'name': 'Denmark'},
#   'timestamp': '00:28:19.800',
#   'type': {'id': 23, 'name': 'Goal Keeper'}},
#  {'duration': 0.0,
#   'id': '03bfb6a7-b633-4dcc-9d9e-38f8dc1dd911',
#   'index': 988,
#   'location': [112.0, 16.0],
#   'minute': 28,
#   'period': 1,
#   'play_pattern': {'id': 6, 'name': 'From Counter'},
#   'player': {'id': 5465, 'name': 'Ante Rebić'},
#   'position': {'id': 12, 'name': 'Right Midfield'},
#   'possession': 46,
#   'possession_team': {'id': 785, 'name': 'Croatia'},
#   'second': 22,
#   'team': {'id': 785, 'name': 'Croatia'},
#   'timestamp': '00:28:22.720',
#   'type': {'id': 2, 'name': 'Ball Recovery'}},
#  {'carry': {'end_location': [115.0, 14.0]},
#   'duration': 1.12,
#   'id': '5852dc96-863c-4d55-a373-79ee9e816eb1',
#   'index': 989,
#   'location': [112.0, 16.0],
#   'minute': 28,
#   'period': 1,
#   'play_pattern': {'id': 6, 'name': 'From Counter'},
#   'player': {'id': 5465, 'name': 'Ante Rebić'},
#   'position': {'id': 12, 'name': 'Right Midfield'},
#   'possession': 46,
#   'possession_team': {'id': 785, 'name': 'Croatia'},
#   'related_events': ['03bfb6a7-b633-4dcc-9d9e-38f8dc1dd911',
#    '4d2c0d45-3c05-4c17-9a83-23f1cfb67ba4',
#    'efe12276-5b64-4bd9-adcf-0e7e3bcc6605'],
#   'second': 22,
#   'team': {'id': 785, 'name': 'Croatia'},
#   'timestamp': '00:28:22.720',
#   'type': {'id': 43, 'name': 'Carry'},
#   'under_pressure': True},
#  {'id': 'efe12276-5b64-4bd9-adcf-0e7e3bcc6605',
#   'index': 990,
#   'location': [6.0, 67.0],
#   'minute': 28,
#   'period': 1,
#   'play_pattern': {'id': 6, 'name': 'From Counter'},
#   'player': {'id': 4763, 'name': 'Henrik Dalsgaard'},
#   'position': {'id': 2, 'name': 'Right Back'},
#   'possession': 46,
#   'possession_team': {'id': 785, 'name': 'Croatia'},
#   'related_events': ['4d2c0d45-3c05-4c17-9a83-23f1cfb67ba4',
#    '5852dc96-863c-4d55-a373-79ee9e816eb1',
#    'd6c2c356-9cf9-46e5-9769-e949de9ce6eb'],
#   'second': 23,
#   'team': {'id': 776, 'name': 'Denmark'},
#   'timestamp': '00:28:23.840',
#   'type': {'id': 39, 'name': 'Dribbled Past'}},
#  {'dribble': {'outcome': {'id': 8, 'name': 'Complete'}},
#   'duration': 0.0,
#   'id': '4d2c0d45-3c05-4c17-9a83-23f1cfb67ba4',
#   'index': 991,
#   'location': [115.0, 14.0],
#   'minute': 28,
#   'period': 1,
#   'play_pattern': {'id': 6, 'name': 'From Counter'},
#   'player': {'id': 5465, 'name': 'Ante Rebić'},
#   'position': {'id': 12, 'name': 'Right Midfield'},
#   'possession': 46,
#   'possession_team': {'id': 785, 'name': 'Croatia'},
#   'related_events': ['efe12276-5b64-4bd9-adcf-0e7e3bcc6605'],
#   'second': 23,
#   'team': {'id': 785, 'name': 'Croatia'},
#   'timestamp': '00:28:23.840',
#   'type': {'id': 14, 'name': 'Dribble'},
#   'under_pressure': True},
#  {'carry': {'end_location': [119.0, 24.0]},
#   'duration': 1.96,
#   'id': 'd6c2c356-9cf9-46e5-9769-e949de9ce6eb',
#   'index': 992,
#   'location': [115.0, 14.0],
#   'minute': 28,
#   'period': 1,
#   'play_pattern': {'id': 6, 'name': 'From Counter'},
#   'player': {'id': 5465, 'name': 'Ante Rebić'},
#   'position': {'id': 12, 'name': 'Right Midfield'},
#   'possession': 46,
#   'possession_team': {'id': 785, 'name': 'Croatia'},
#   'related_events': ['47e43699-7c6d-4dc1-8e3a-0a298eb6dfc6',
#    '4d2c0d45-3c05-4c17-9a83-23f1cfb67ba4',
#    'efe12276-5b64-4bd9-adcf-0e7e3bcc6605'],
#   'second': 23,
#   'team': {'id': 785, 'name': 'Croatia'},
#   'timestamp': '00:28:23.840',
#   'type': {'id': 43, 'name': 'Carry'},
#   'under_pressure': True},
#  {'duration': 0.693,
#   'id': '47e43699-7c6d-4dc1-8e3a-0a298eb6dfc6',
#   'index': 993,
#   'location': [119.0, 24.0],
#   'minute': 28,
#   'pass': {'angle': 1.6539376,
#    'body_part': {'id': 40, 'name': 'Right Foot'},
#    'cross': True,
#    'end_location': [118.0, 36.0],
#    'height': {'id': 3, 'name': 'High Pass'},
#    'length': 12.0415945,
#    'outcome': {'id': 9, 'name': 'Incomplete'},
#    'recipient': {'id': 5472, 'name': 'Mario Mandžukić'}},
#   'period': 1,
#   'play_pattern': {'id': 6, 'name': 'From Counter'},
#   'player': {'id': 5465, 'name': 'Ante Rebić'},
#   'position': {'id': 12, 'name': 'Right Midfield'},
#   'possession': 46,
#   'possession_team': {'id': 785, 'name': 'Croatia'},
#   'related_events': ['8de8d248-72f9-4323-98b9-16b27c2396f2',
#    'c898fd95-d1a4-4a70-9a0d-f0ec154ed083'],
#   'second': 25,
#   'team': {'id': 785, 'name': 'Croatia'},
#   'timestamp': '00:28:25.800',
#   'type': {'id': 30, 'name': 'Pass'}},
#  {'ball_receipt': {'outcome': {'id': 9, 'name': 'Incomplete'}},
#   'id': '8de8d248-72f9-4323-98b9-16b27c2396f2',
#   'index': 994,
#   'location': [113.0, 48.0],
#   'minute': 28,
#   'period': 1,
#   'play_pattern': {'id': 6, 'name': 'From Counter'},
#   'player': {'id': 5472, 'name': 'Mario Mandžukić'},
#   'position': {'id': 23, 'name': 'Center Forward'},
#   'possession': 46,
#   'possession_team': {'id': 785, 'name': 'Croatia'},
#   'related_events': ['47e43699-7c6d-4dc1-8e3a-0a298eb6dfc6'],
#   'second': 26,
#   'team': {'id': 785, 'name': 'Croatia'},
#   'timestamp': '00:28:26.493',
#   'type': {'id': 42, 'name': 'Ball Receipt*'}},
#  {'goalkeeper': {'outcome': {'id': 50, 'name': 'Fail'},
#    'type': {'id': 25, 'name': 'Collected'}},
#   'id': 'c898fd95-d1a4-4a70-9a0d-f0ec154ed083',
#   'index': 995,
#   'location': [3.0, 45.0],
#   'minute': 28,
#   'period': 1,
#   'play_pattern': {'id': 6, 'name': 'From Counter'},
#   'player': {'id': 3815, 'name': 'Kasper Schmeichel'},
#   'position': {'id': 1, 'name': 'Goalkeeper'},
#   'possession': 46,
#   'possession_team': {'id': 785, 'name': 'Croatia'},
#   'related_events': ['47e43699-7c6d-4dc1-8e3a-0a298eb6dfc6'],
#   'second': 26,
#   'team': {'id': 776, 'name': 'Denmark'},
#   'timestamp': '00:28:26.493',
#   'type': {'id': 23, 'name': 'Goal Keeper'}},
#  {'duration': 0.96,
#   'id': '666dcde1-95a8-4462-b1d7-579d9e8d993b',
#   'index': 996,
#   'location': [118.0, 32.0],
#   'minute': 28,
#   'pass': {'angle': 3.1415927,
#    'assisted_shot_id': '8b5b8fbc-1fb7-4704-891c-be5fae88efd4',
#    'body_part': {'id': 40, 'name': 'Right Foot'},
#    'end_location': [111.0, 32.0],
#    'height': {'id': 2, 'name': 'Low Pass'},
#    'length': 7.0,
#    'recipient': {'id': 5474, 'name': 'Ivan Perišić'},
#    'shot_assist': True,
#    'type': {'id': 66, 'name': 'Recovery'}},
#   'period': 1,
#   'play_pattern': {'id': 6, 'name': 'From Counter'},
#   'player': {'id': 5470, 'name': 'Ivan Rakitić'},
#   'position': {'id': 15, 'name': 'Left Center Midfield'},
#   'possession': 46,
#   'possession_team': {'id': 785, 'name': 'Croatia'},
#   'related_events': ['8e697ba0-985b-4da1-bca9-a938fc368a6a'],
#   'second': 27,
#   'team': {'id': 785, 'name': 'Croatia'},
#   'timestamp': '00:28:27.640',
#   'type': {'id': 30, 'name': 'Pass'}},
#  {'id': '8e697ba0-985b-4da1-bca9-a938fc368a6a',
#   'index': 997,
#   'location': [111.0, 32.0],
#   'minute': 28,
#   'period': 1,
#   'play_pattern': {'id': 6, 'name': 'From Counter'},
#   'player': {'id': 5474, 'name': 'Ivan Perišić'},
#   'position': {'id': 16, 'name': 'Left Midfield'},
#   'possession': 46,
#   'possession_team': {'id': 785, 'name': 'Croatia'},
#   'related_events': ['666dcde1-95a8-4462-b1d7-579d9e8d993b'],
#   'second': 28,
#   'team': {'id': 785, 'name': 'Croatia'},
#   'timestamp': '00:28:28.600',
#   'type': {'id': 42, 'name': 'Ball Receipt*'}},
#  {'duration': 0.973,
#   'id': '8b5b8fbc-1fb7-4704-891c-be5fae88efd4',
#   'index': 998,
#   'location': [110.0, 32.0],
#   'minute': 28,
#   'period': 1,
#   'play_pattern': {'id': 6, 'name': 'From Counter'},
#   'player': {'id': 5474, 'name': 'Ivan Perišić'},
#   'position': {'id': 16, 'name': 'Left Midfield'},
#   'possession': 46,
#   'possession_team': {'id': 785, 'name': 'Croatia'},
#   'related_events': ['6e987508-367c-4a51-9c87-3fe95f0b3f51'],
#   'second': 28,
#   'shot': {'body_part': {'id': 38, 'name': 'Left Foot'},
#    'end_location': [113.0, 34.0],
#    'first_time': True,
#    'freeze_frame': [{'location': [107.0, 14.0],
#      'player': {'id': 5536, 'name': 'Yussuf Yurary Poulsen'},
#      'position': {'id': 17, 'name': 'Right Wing'},
#      'teammate': False},
#     {'location': [102.0, 52.0],
#      'player': {'id': 4447, 'name': 'Martin Braithwaite Christensen'},
#      'position': {'id': 21, 'name': 'Left Wing'},
#      'teammate': False},
#     {'location': [99.0, 51.0],
#      'player': {'id': 5461, 'name': 'Šime Vrsaljko'},
#      'position': {'id': 2, 'name': 'Right Back'},
#      'teammate': True},
#     {'location': [101.0, 30.0],
#      'player': {'id': 3043, 'name': 'Christian Dannemann Eriksen'},
#      'position': {'id': 25, 'name': 'Secondary Striker'},
#      'teammate': False},
#     {'location': [116.0, 42.0],
#      'player': {'id': 6355, 'name': 'Jonas Knudsen'},
#      'position': {'id': 6, 'name': 'Left Back'},
#      'teammate': False},
#     {'location': [117.0, 37.0],
#      'player': {'id': 3815, 'name': 'Kasper Schmeichel'},
#      'position': {'id': 1, 'name': 'Goalkeeper'},
#      'teammate': False},
#     {'location': [113.0, 45.0],
#      'player': {'id': 5527, 'name': 'Thomas Delaney'},
#      'position': {'id': 15, 'name': 'Left Center Midfield'},
#      'teammate': False},
#     {'location': [118.0, 42.0],
#      'player': {'id': 5472, 'name': 'Mario Mandžukić'},
#      'position': {'id': 23, 'name': 'Center Forward'},
#      'teammate': True},
#     {'location': [115.0, 38.0],
#      'player': {'id': 3027, 'name': 'Mathias Jattah-Njie Jørgensen'},
#      'position': {'id': 5, 'name': 'Left Center Back'},
#      'teammate': False},
#     {'location': [119.0, 27.0],
#      'player': {'id': 5470, 'name': 'Ivan Rakitić'},
#      'position': {'id': 15, 'name': 'Left Center Midfield'},
#      'teammate': True},
#     {'location': [117.0, 30.0],
#      'player': {'id': 5465, 'name': 'Ante Rebić'},
#      'position': {'id': 12, 'name': 'Right Midfield'},
#      'teammate': True},
#     {'location': [118.0, 32.0],
#      'player': {'id': 3959, 'name': 'Andreas Christensen'},
#      'position': {'id': 13, 'name': 'Right Center Midfield'},
#      'teammate': False},
#     {'location': [119.0, 31.0],
#      'player': {'id': 5534, 'name': 'Simon Thorup Kjær'},
#      'position': {'id': 3, 'name': 'Right Center Back'},
#      'teammate': False},
#     {'location': [117.0, 29.0],
#      'player': {'id': 4763, 'name': 'Henrik Dalsgaard'},
#      'position': {'id': 2, 'name': 'Right Back'},
#      'teammate': False},
#     {'location': [95.0, 34.0],
#      'player': {'id': 5463, 'name': 'Luka Modrić'},
#      'position': {'id': 13, 'name': 'Right Center Midfield'},
#      'teammate': True}],
#    'key_pass_id': '666dcde1-95a8-4462-b1d7-579d9e8d993b',
#    'outcome': {'id': 101, 'name': 'Wayward'},
#    'statsbomb_xg': 0.20444514,
#    'technique': {'id': 91, 'name': 'Half Volley'},
#    'type': {'id': 87, 'name': 'Open Play'}},
#   'team': {'id': 785, 'name': 'Croatia'},
#   'timestamp': '00:28:28.600',
#   'type': {'id': 16, 'name': 'Shot'}},
#  {'goalkeeper': {'end_location': [5.0, 42.0],
#    'position': {'id': 42, 'name': 'Moving'},
#    'type': {'id': 32, 'name': 'Shot Faced'}},
#   'id': '6e987508-367c-4a51-9c87-3fe95f0b3f51',
#   'index': 999,
#   'location': [4.0, 44.0],
#   'minute': 28,
#   'period': 1,
#   'play_pattern': {'id': 6, 'name': 'From Counter'},
#   'player': {'id': 3815, 'name': 'Kasper Schmeichel'},
#   'position': {'id': 1, 'name': 'Goalkeeper'},
#   'possession': 46,
#   'possession_team': {'id': 785, 'name': 'Croatia'},
#   'related_events': ['8b5b8fbc-1fb7-4704-891c-be5fae88efd4'],
#   'second': 29,
#   'team': {'id': 776, 'name': 'Denmark'},
#   'timestamp': '00:28:29.573',
#   'type': {'id': 23, 'name': 'Goal Keeper'}},
#  {'duration': 0.0,
#   'id': '4fc1ce6b-10f9-47ab-87ca-2d6025e30672',
#   'index': 1000,
#   'location': [111.0, 35.0],
#   'minute': 28,
#   'period': 1,
#   'play_pattern': {'id': 6, 'name': 'From Counter'},
#   'player': {'id': 5474, 'name': 'Ivan Perišić'},
#   'position': {'id': 16, 'name': 'Left Midfield'},
#   'possession': 46,
#   'possession_team': {'id': 785, 'name': 'Croatia'},
#   'second': 29,
#   'team': {'id': 785, 'name': 'Croatia'},
#   'timestamp': '00:28:29.880',
#   'type': {'id': 2, 'name': 'Ball Recovery'}},
#  ...]

# %%
pd.json_normalize(event_json)
# Out:
#                                         id  ...  foul_won.penalty
# 0     0aa135b8-37b4-4482-adc7-f02e85a19bec  ...               NaN
# 1     086b7750-936b-4ffd-9a00-bfd72c7a0f26  ...               NaN
# 2     53f0c3f9-129e-47b5-ba77-ae9d214df56f  ...               NaN
# 3     49233ae2-594f-43c9-a58c-a6a0b8f99ee2  ...               NaN
# 4     ec5ba260-9bd3-4c5a-b7a5-9f9168ea905d  ...               NaN
# ...                                    ...  ...               ...
# 4282  4a20f5ba-b5c3-4ac4-afa3-70f61feb3815  ...               NaN
# 4283  204dcb31-bf2a-448e-aac2-086a65c7d699  ...               NaN
# 4284  c21dc873-7130-420e-a3f7-f2292b8be8fb  ...               NaN
# 4285  e7268957-e073-4e77-b021-c8e481f58131  ...               NaN
# 4286  4ca42e5b-fabd-4184-99e5-1410f6a98834  ...               NaN
#
# [4287 rows x 110 columns]

# %%
event_df = pd.json_normalize(event_json)

# %%
event_df.columns.values
# Out:
# array(['id', 'index', 'period', 'timestamp', 'minute', 'second',
#        'possession', 'duration', 'type.id', 'type.name',
#        'possession_team.id', 'possession_team.name', 'play_pattern.id',
#        'play_pattern.name', 'team.id', 'team.name', 'tactics.formation',
#        'tactics.lineup', 'related_events', 'location', 'player.id',
#        'player.name', 'position.id', 'position.name', 'pass.recipient.id',
#        'pass.recipient.name', 'pass.length', 'pass.angle',
#        'pass.height.id', 'pass.height.name', 'pass.end_location',
#        'pass.body_part.id', 'pass.body_part.name', 'pass.type.id',
#        'pass.type.name', 'under_pressure', 'carry.end_location',
#        'pass.outcome.id', 'pass.outcome.name', 'pass.aerial_won',
#        'duel.type.id', 'duel.type.name', 'ball_receipt.outcome.id',
#        'ball_receipt.outcome.name', 'pass.switch',
#        'pass.assisted_shot_id', 'pass.goal_assist', 'shot.statsbomb_xg',
#        'shot.end_location', 'shot.key_pass_id', 'shot.outcome.id',
#        'shot.outcome.name', 'shot.body_part.id', 'shot.body_part.name',
#        'shot.type.id', 'shot.type.name', 'shot.technique.id',
#        'shot.technique.name', 'shot.freeze_frame',
#        'goalkeeper.outcome.id', 'goalkeeper.outcome.name',
#        'goalkeeper.body_part.id', 'goalkeeper.body_part.name',
#        'goalkeeper.type.id', 'goalkeeper.type.name',
#        'goalkeeper.position.id', 'goalkeeper.position.name',
#        'goalkeeper.technique.id', 'goalkeeper.technique.name',
#        'shot.first_time', 'counterpress', 'foul_committed.offensive',
#        'foul_won.defensive', 'pass.cross', 'goalkeeper.end_location',
#        'clearance.aerial_won', 'dribble.outcome.id',
#        'dribble.outcome.name', 'duel.outcome.id', 'duel.outcome.name',
#        'pass.deflected', 'block.offensive', 'block.deflection',
#        'dribble.overrun', 'pass.shot_assist', 'interception.outcome.id',
#        'interception.outcome.name', 'miscontrol.aerial_won',
#        'ball_recovery.recovery_failure', 'foul_committed.advantage',
#        'foul_won.advantage', 'dribble.nutmeg', 'shot.aerial_won',
#        'pass.backheel', '50_50.outcome.id', '50_50.outcome.name',
#        'ball_recovery.offensive', 'substitution.outcome.id',
#        'substitution.outcome.name', 'substitution.replacement.id',
#        'substitution.replacement.name', 'foul_committed.type.id',
#        'foul_committed.type.name', 'pass.through_ball',
#        'pass.technique.id', 'pass.technique.name',
#        'foul_committed.card.id', 'foul_committed.card.name',
#        'foul_committed.penalty', 'foul_won.penalty'], dtype=object)

# %%
event_df["type.name"].unique()
# Out:
# array(['Starting XI', 'Half Start', 'Pass', 'Ball Receipt*', 'Carry',
#        'Pressure', 'Duel', 'Shot', 'Goal Keeper', 'Camera On',
#        'Miscontrol', 'Ball Recovery', 'Clearance', 'Block',
#        'Foul Committed', 'Foul Won', 'Camera off', 'Dribble',
#        'Dispossessed', 'Dribbled Past', 'Interception', '50/50',
#        'Injury Stoppage', 'Player Off', 'Referee Ball-Drop', 'Player On',
#        'Half End', 'Substitution', 'Shield', 'Error', 'Offside',
#        'Tactical Shift'], dtype=object)

# %% [markdown]
# ## Event data for La Liga 2019-20

# %%
match_id_list = season_meta_data_df.loc[season_meta_data_df["season.season_id"] == 3, "match_id"].unique()

# %%
match_id_list
# Out:
# array([7581, 7549, 7555, 7529, 7548, 7534, 7562, 7565, 7571, 7569, 7568,
#        7530, 7558, 7583, 8652, 7547, 7535, 7546, 7584, 7536, 7545, 7580,
#        8650, 8649, 8658, 7561, 7539, 7563, 7578, 7531, 7582, 7552, 7532,
#        7544, 7553, 7560, 7533, 7564, 7556, 7559, 7579, 7572, 7577, 7543,
#        7525, 7538, 7576, 7542, 7566, 7557, 7554, 7570, 7585, 7586, 8656,
#        8651, 7567, 7541, 8655, 8657, 7540, 7551, 7550, 7537])

# %%
matchwise_events_df = pd.DataFrame()
for m_id in match_id_list:
    print("Working on", m_id)
    event_json = requests.get(url=event_url.format(m_id)).json()
    df = pd.json_normalize(event_json)
    df.insert(0, "match_id", m_id)
    matchwise_events_df = matchwise_events_df.append(df)
# Out:
# Working on 7581
# Working on 7549
# Working on 7555
# Working on 7529
# Working on 7548
# Working on 7534
# Working on 7562
# Working on 7565
# Working on 7571
# Working on 7569
# Working on 7568
# Working on 7530
# Working on 7558
# Working on 7583
# Working on 8652
# Working on 7547
# Working on 7535
# Working on 7546
# Working on 7584
# Working on 7536
# Working on 7545
# Working on 7580
# Working on 8650
# Working on 8649
# Working on 8658
# Working on 7561
# Working on 7539
# Working on 7563
# Working on 7578
# Working on 7531
# Working on 7582
# Working on 7552
# Working on 7532
# Working on 7544
# Working on 7553
# Working on 7560
# Working on 7533
# Working on 7564
# Working on 7556
# Working on 7559
# Working on 7579
# Working on 7572
# Working on 7577
# Working on 7543
# Working on 7525
# Working on 7538
# Working on 7576
# Working on 7542
# Working on 7566
# Working on 7557
# Working on 7554
# Working on 7570
# Working on 7585
# Working on 7586
# Working on 8656
# Working on 8651
# Working on 7567
# Working on 7541
# Working on 8655
# Working on 8657
# Working on 7540
# Working on 7551
# Working on 7550
# Working on 7537

# %%
matchwise_events_df.head()
# Out:
#    match_id  ... shot.follows_dribble
# 0      7581  ...                  NaN
# 1      7581  ...                  NaN
# 2      7581  ...                  NaN
# 3      7581  ...                  NaN
# 4      7581  ...                  NaN
#
# [5 rows x 122 columns]

# %%
# Save data to csv file on your local system
matchwise_events_df.to_csv('matchwise_events_data.csv')
files.download('matchwise_events_data.csv')

# %%
matchwise_events_df.shape
# Out:
# (227886, 122)
